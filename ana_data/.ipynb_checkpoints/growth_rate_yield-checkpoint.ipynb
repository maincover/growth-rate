# %%
csv_folder_path = './carbon_source'

# %%
def smooth(a,WSZ=5):
    # a: NumPy 1-D array containing the data to be smoothed
    # WSZ: smoothing window size needs, which must be odd number,
    # as in the original MATLAB implementation
    out0 = np.convolve(a,np.ones(WSZ,dtype=int),'valid')/WSZ    
    r = np.arange(1,WSZ-1,2)

    start = np.cumsum(a[:WSZ-1])[::2]/r
    #print start,out0
    stop = (np.cumsum(a[:-WSZ:-1])[::2]/r)[::-1]
    return np.concatenate((  start , out0, stop  ))

def digitalOnly(s):
    import string
    al=string.maketrans('','')
    nodigs=al.translate(al, string.digits)
    return s.translate(al, nodigs)

def getLinearRegressionCoef(X,y):
    import numpy as np
    from sklearn.linear_model import LinearRegression
    reg = LinearRegression().fit(X, y)
    reg.score(X, y)    
    return reg.coef_


def computeDerivetive_od(t, sOD, wsz = 5):
    from numpy import isnan
    coef_OD = np.zeros(len(sOD))
    t_mean = np.zeros(len(sOD))
    j = 0
    nan_found = False
    for i in range(len(sOD)):
        t_wsz = t[i-wsz/2:i+wsz/2+1]        
        sOD_wsz = np.expand_dims(np.log(sOD[i-wsz/2:i+wsz/2+1]),axis=1)    
        if len(sOD_wsz)!= wsz:
            coef_OD[i] = 0
        else:                
            if len(t_wsz)==len(sOD_wsz):                
                where_are_NaNs = isnan(sOD_wsz)
                if any(where_are_NaNs):
                    sOD_wsz[where_are_NaNs] = np.mean(sOD_wsz[~where_are_NaNs])
                    print "nan Found in array, replaced by mean value of the rest",i
                coef_OD[i]=getLinearRegressionCoef(t_wsz,sOD_wsz)
                t_mean[i] = np.mean(t_wsz)
    
    dt = t_mean[wsz/2:len(t_mean)-wsz/2]
    dt_pad = np.pad(dt,[wsz/2,wsz/2],'reflect',reflect_type='odd')
    
    return coef_OD, dt_pad


def draw_tangent(x1,y1,ind,e=0.1,plot=False):
    from scipy import interpolate
    import numpy as np
    import matplotlib.pyplot as plt
    x = np.squeeze(x1)
    y = np.squeeze(y1)
    # interpolate the data with a spline
    spl = interpolate.splrep(x,y)
    a = x[ind]
    fa = interpolate.splev(a,spl,der=0)     # f(a)
    fprime = interpolate.splev(a,spl,der=1) # f'(a)
    left = 0
    for i in range(ind,0,-1):        
        a_i = x[i]
        y_i = y[i]        
        tan_i = fa+fprime*(a_i-a) # tangent                
        if abs(tan_i-y_i) > abs(y[ind]*e):
            left = i
            break    
    right = len(x) - 1
    for i in range(ind+1,len(x)):        
        a_i = x[i]
        y_i = y[i]
        tan_i = fa+fprime*(a_i-a) # tangent        
        if abs(tan_i-y_i) > abs(y[ind]*e):
            right = i
            break
    small_t = np.linspace(x[left],x[right],10)
    tan = fa+fprime*(small_t-a) # tangent    
    if plot:
        plt.plot(a,fa,'om',small_t,tan,'--r')
        plt.plot(x,y)
    return left, right,small_t,tan


def getTimepoints_old(coef_OD,sOD_log, dt_pad,start_ind, thres=0.03, thres_range=0.8):
    coef_OD_fromStart_ind = coef_OD[start_ind:]
    ind = np.argmax(coef_OD_fromStart_ind) + start_ind        
    max_v = coef_OD[ind]
    
    time_max_coefod = dt_pad[ind]        
    right_side_exp = len(coef_OD)-1
    left_side_exp = 0
    for k in range(ind+1,len(coef_OD)):
        v_od = coef_OD[k]
        if (max_v-v_od)/max_v > 1-thres_range:
            right_side_exp = k
            break

    for k in reversed(range(ind)):
        v_od = coef_OD[k]
        if (max_v-v_od)/max_v > 1-thres_range:
            left_side_exp = k
            break

    time_left = dt_pad[left_side_exp]
    time_right = dt_pad[right_side_exp]  
    
    return time_max_coefod,time_left,time_right,left_side_exp,right_side_exp

def getTimepoints(coef_OD,sOD_log,dt_pad,start_ind):
    coef_OD_fromStart_ind = coef_OD[start_ind:]
    ind = np.argmax(coef_OD_fromStart_ind) + start_ind        
    max_v = coef_OD[ind]
    time_max_coefod = dt_pad[ind]        
    left_side_exp, right_side_exp,small_t,tan = draw_tangent(dt_pad,sOD_log,ind)
    time_left = dt_pad[left_side_exp]
    time_right = dt_pad[right_side_exp]  
    return time_max_coefod,time_left,time_right,left_side_exp,right_side_exp,small_t,tan, ind


def getPostiveStart(sOD):
    start_positive = 0
    for o in range(start_positive, len(sOD)):
        if sOD[o] <= 0:
            start_positive = o + 1
    if start_positive >= len(sOD):
        start_positive = -1
    return start_positive

def mkdir_p(path):
    import errno    
    import os
    try:
        os.makedirs(path)
    except OSError as exc:  # Python >2.5
        if exc.errno == errno.EEXIST and os.path.isdir(path):
            pass
        else:
            raise
            
            
def getStationaryTime(sOD):
    sOD = np.asarray(sOD)
    sta_index = len(sOD)-1
    last_value = sOD[sta_index]
    for i in range(len(sOD)-2,0,-1):
        if (abs(last_value-sOD[i])/last_value)>0.05:
            sta_index = i
            #print "stationary phase found"
            break
    return sta_index

def mkdir_p(path):
    import errno    
    import os
    try:
        os.makedirs(path)
    except OSError as exc:  # Python >2.5
        if exc.errno == errno.EEXIST and os.path.isdir(path):
            pass
        else:
            raise

# %%
import os
import pandas as pd

def getfiles(folderPath):
    pths = []
    for root, dirs, files in os.walk(folderPath):
        for fn in files:            
            if fn.endswith('.csv') and 'stats' not in fn:
                pth = os.path.join(root, fn)
                pths.append(pth)
    return pths

pths = getfiles(csv_folder_path)

for path in pths:
    folder = path.split('.')[0]
    mkdir_p(folder)
    # pay attention of the csv format, if sep = ',' or ";"
    data = pd.read_csv(path,sep=';')    
    
    import numpy as np
    import matplotlib.pyplot as plt
    import os
    time = data.iloc[:,0]
    m_od = data.iloc[0:,1:]
    strains = list(m_od.columns)
    t = time.values

    t_k = (t[1:len(t)] - t[0:len(t)-1])/3600
    t_k = np.cumsum(t_k)
    t_k = np.insert(t_k,0,0)
    t_k = t_k.reshape(-1,1)
    t = t_k

    blank_od = 0.04
    pre_max_v = 0.7

    growth_rate_dict = dict()
    lag_phase_dict = dict()
    yield_dict = dict()
    for name in strains:
        od = m_od[name].values
        od_array = od - np.min(blank_od)
        od_array = np.squeeze(np.asarray(od_array))
        sOD = smooth(od_array)    
        
        start_positive = getPostiveStart(sOD)
        t = t_k
        if start_positive > 0:
            sOD = sOD[start_positive:]
            od = od[start_positive:]
            t = t_k[start_positive:]
            print name,'found negative od ', start_positive
        
        
        sOD_log = np.log(sOD)            
        coef_OD, dt_pad = computeDerivetive_od(t, sOD)
        
        #try:
        #    coef_OD, dt_pad = computeDerivetive_od(t, sOD)
        #except:
        #    continue
            
        ind_max_dODdt = np.argmax(coef_OD)
        OD_exp = sOD[ind_max_dODdt]
        time_max_dODdt = dt_pad[ind_max_dODdt]
  
        lag_phase_pre = time_max_dODdt - np.log(OD_exp/sOD[start_positive])/pre_max_v
        m = t < lag_phase_pre
        start_ind = np.sum(m)

        time_max_od,time_left, time_right,left_side_exp,right_side_exp,small_t,tan,ind_max = getTimepoints(coef_OD,sOD_log,dt_pad,start_ind)

        time_max_dODdt = dt_pad[ind_max_dODdt]

        #od_max_coef = coef_OD[ind_max_dODdt]

        #ind = np.argmax(coef_OD)        
        max_v = coef_OD[ind_max]  
        #print "diffrence from estimate and real : ", ind, ind_max
        growth_rate = max_v

        
        
        # Update lag_phase using growth rate in an estimated window
        lag_phase_pre = time_max_dODdt - np.log(OD_exp/sOD[start_positive])/max_v
        lag_phase = lag_phase_pre

        sta_index = getStationaryTime(sOD)
        t_sta = dt_pad[sta_index]

        yield_mean = np.mean(sOD[sta_index:])
        print name+' yield'+"="+str(yield_mean)
        print name+' growth_rate'+"="+str(growth_rate)
        print "---------------------------------------"

        x = t
        y = sOD_log
        plt.plot(x,y,label='log(OD)')
        plt.plot(x,y,small_t,tan,'--r',label='log(OD)')
        plt.title(name)
        plt.xlabel("time")
        w = coef_OD
        plt.plot(x, w,label='dOD/dt/OD') # can c                
        plt.axvline(x=time_max_od,linestyle=':',color='orange')
        plt.legend()
        plt.savefig(os.path.join(folder,name +'-dODdtOD.png'))
        plt.close()   

        plt.plot(x,sOD,label='OD')    
        plt.axvline(x=time_left,linestyle=':',color='red')
        plt.axvline(x=time_max_od,linestyle=':',color='green')
        plt.axvline(x=t_sta,linestyle=':',color='yellow')
        plt.axvline(x=time_right,linestyle=':',color='red')
        plt.axvline(x=lag_phase,linestyle=':',color='purple')    
        plt.xlabel('time')
        plt.title(name)        
        plt.legend()
        plt.savefig(os.path.join(folder,name +'-OD.png'))
        plt.close()
        
        growth_rate_dict[name] = growth_rate
        lag_phase_dict[name] = lag_phase
        yield_dict[name] = yield_mean

    df = pd.DataFrame.from_dict([growth_rate_dict,lag_phase_dict, yield_dict])
    df = df.transpose()
    df2 = df.reindex(strains)
    df2.columns = ['Growth Rate', 'Lag Phase', 'yield']
    df2.to_csv(folder +'-stats.csv')
# Out:
# DLmalate10_R1 yield=0.2882315789473684
# DLmalate10_R1 growth_rate=0.37578228851744067
# ---------------------------------------
# DLmalate10_R2 yield=0.39273723577235775
# DLmalate10_R2 growth_rate=0.6182038909813192
# ---------------------------------------
# DLmalate10_R3 yield=0.2717381699346405
# DLmalate10_R3 growth_rate=0.6718420560898659
# ---------------------------------------
# DLmalate25_R1 yield=0.03336666666666666
# DLmalate25_R1 growth_rate=1.5842455233445811
# ---------------------------------------
# DLmalate25_R2 yield=0.04369533333333333
# DLmalate25_R2 growth_rate=1.317224837793264
# ---------------------------------------
# DLmalate25_R3 yield=0.05236933333333334
# DLmalate25_R3 growth_rate=1.4114643548561727
# ---------------------------------------
# DLmalate50_R1 yield=0.0032833333333333334
# DLmalate50_R1 growth_rate=0.54223837233382
# ---------------------------------------
# DLmalate50_R2 yield=0.005383333333333332
# DLmalate50_R2 growth_rate=1.3105177235480132
# ---------------------------------------
# DLmalate50_R3 yield=0.0033
# DLmalate50_R3 growth_rate=0.7751575887520034
# ---------------------------------------
# glc0.4_R1 yield=0.6601026666666665
# glc0.4_R1 growth_rate=0.6520945770581612
# ---------------------------------------
# glc0.4_R2 yield=0.5646269135802467
# glc0.4_R2 growth_rate=0.6887033833570607
# ---------------------------------------
# glc0.4_R3 yield=0.5234457142857143
# glc0.4_R3 growth_rate=0.6773767940603828
# ---------------------------------------
# glucuronica10_R1 yield=0.48391333333333336
# glucuronica10_R1 growth_rate=0.5025436815962552
# ---------------------------------------
# glucuronica10_R2 yield=0.4497126984126984
# glucuronica10_R2 growth_rate=0.6026199312676604
# ---------------------------------------
# glucuronica10_R3 yield=0.4511133333333333
# glucuronica10_R3 growth_rate=0.9743105095995171
# ---------------------------------------
# glucuronica25_R1 yield=0.7285993333333334
# glucuronica25_R1 growth_rate=0.39678783054575884
# ---------------------------------------
# glucuronica25_R2 yield=0.7426959999999999
# glucuronica25_R2 growth_rate=0.41246074842719205
# ---------------------------------------
# glucuronica25_R3 yield=0.6198872222222223
# glucuronica25_R3 growth_rate=0.4586705240029691
# ---------------------------------------
# glucuronica50_R1 yield=0.6699420512820512
# glucuronica50_R1 growth_rate=0.878383365152669
# ---------------------------------------
# glucuronica50_R2 yield=0.6618223999999999
# glucuronica50_R2 growth_rate=0.5013228373577852
# ---------------------------------------
# glucuronica50_R3 yield=0.6345466666666666
# glucuronica50_R3 growth_rate=0.46865416071755495
# ---------------------------------------
# ketobutyrica1_R1 yield=0.05888222222222223
# ketobutyrica1_R1 growth_rate=1.018584470441017
# ---------------------------------------
# ketobutyrica1_R2 yield=0.02453611111111111
# ketobutyrica1_R2 growth_rate=0.3108218579300583
# ---------------------------------------
# ketobutyrica1_R3 yield=0.029038666666666664
# ketobutyrica1_R3 growth_rate=0.7791812144168256
# ---------------------------------------
# ketobutyrica2_R1 yield=0.024093333333333335
# ketobutyrica2_R1 growth_rate=0.8961956827673268
# ---------------------------------------
# ketobutyrica2_R2 yield=0.024686111111111114
# ketobutyrica2_R2 growth_rate=0.2517601422609773
# ---------------------------------------
# ketobutyrica2_R3 yield=0.021118888888888892
# ketobutyrica2_R3 growth_rate=0.17251480366424088
# ---------------------------------------
# ketobutyrica5_R1 yield=0.023455238095238095
# ketobutyrica5_R1 growth_rate=1.3611909864268033
# ---------------------------------------
# ketobutyrica5_R2 yield=0.1546
# ketobutyrica5_R2 growth_rate=4.46915189746288
# ---------------------------------------
# ketobutyrica5_R3 yield=0.11135111111111111
# ketobutyrica5_R3 growth_rate=3.267471199766087
# ---------------------------------------
# Llactate10_R1 yield=0.2193793939393939
# Llactate10_R1 growth_rate=0.3512122847760008
# ---------------------------------------
# Llactate10_R2 yield=0.21333629629629625
# Llactate10_R2 growth_rate=0.3505440870300456
# ---------------------------------------
# Llactate10_R3 yield=0.21374598290598293
# Llactate10_R3 growth_rate=0.3794840818844766
# ---------------------------------------
# Llactate25_R1 yield=0.6003355555555554
# Llactate25_R1 growth_rate=0.5023134060637077
# ---------------------------------------
# Llactate25_R2 yield=0.5647559999999999
# Llactate25_R2 growth_rate=0.32234818319914244
# ---------------------------------------
# Llactate25_R3 yield=0.6440470175438596
# Llactate25_R3 growth_rate=0.3292262346941164
# ---------------------------------------
# Llactate5_R1 yield=0.12207633333333331
# Llactate5_R1 growth_rate=0.48442934472293175
# ---------------------------------------
# Llactate5_R2 yield=0.11286740740740742
# Llactate5_R2 growth_rate=0.5878475927358114
# ---------------------------------------
# Llactate5_R3 yield=0.09986633333333332
# Llactate5_R3 growth_rate=0.523041976217925
# ---------------------------------------
# methylpyr10_R1 yield=0.1809192307692308
# methylpyr10_R1 growth_rate=0.4534341335375928
# ---------------------------------------
# methylpyr10_R2 yield=0.26660249999999996
# methylpyr10_R2 growth_rate=0.4126210613991246
# ---------------------------------------
# methylpyr10_R3 yield=0.1808880833333333
# methylpyr10_R3 growth_rate=0.6245400213717471
# ---------------------------------------
# methylpyr25_R1 yield=0.5010153333333334
# methylpyr25_R1 growth_rate=0.3681212609969852
# ---------------------------------------
# methylpyr25_R2 yield=0.5134703030303029
# methylpyr25_R2 growth_rate=0.3584876014794753
# ---------------------------------------
# methylpyr25_R3 yield=0.508109090909091
# methylpyr25_R3 growth_rate=0.36304597458074284
# ---------------------------------------
# methylpyr5_R1 yield=0.12128142857142855
# methylpyr5_R1 growth_rate=0.38407713656297887
# ---------------------------------------
# methylpyr5_R2 yield=0.11375444444444444
# methylpyr5_R2 growth_rate=0.41137388595363916
# ---------------------------------------
# methylpyr5_R3 yield=0.09740579710144924
# methylpyr5_R3 growth_rate=0.6404061625850299
# ---------------------------------------
# Saccharicac0.9_R1 yield=0.06034733333333332
# Saccharicac0.9_R1 growth_rate=0.5000844324894225
# ---------------------------------------
# Saccharicac0.9_R2 yield=0.04323958333333333
# Saccharicac0.9_R2 growth_rate=0.32497013134363095
# ---------------------------------------
# Saccharicac0.9_R3 yield=0.06655809523809524
# Saccharicac0.9_R3 growth_rate=0.4686573012408294
# ---------------------------------------
# Saccharicac18_R1 yield=0.6427627777777777
# Saccharicac18_R1 growth_rate=0.3422676130470388
# ---------------------------------------
# Saccharicac18_R2 yield=0.5968379487179487
# Saccharicac18_R2 growth_rate=0.35203941478592526
# ---------------------------------------
# Saccharicac18_R3 yield=0.6174638888888889
# Saccharicac18_R3 growth_rate=0.3317357155346569
# ---------------------------------------
# Saccharicac9_R1 yield=0.4264903703703704
# Saccharicac9_R1 growth_rate=0.4021176013667937
# ---------------------------------------
# Saccharicac9_R2 yield=0.3977622222222222
# Saccharicac9_R2 growth_rate=0.3607754796439575
# ---------------------------------------
# Saccharicac9_R3 yield=0.3732160000000001
# Saccharicac9_R3 growth_rate=0.34296897913748
# ---------------------------------------
# Acetate10_R1 yield=0.2888744444444445
# Acetate10_R1 growth_rate=0.5503626180366853
# ---------------------------------------
# Acetate10_R2 yield=0.21331714285714282
# Acetate10_R2 growth_rate=0.5397185156922133
# ---------------------------------------
# Acetate10_R3 yield=0.20805185185185182
# Acetate10_R3 growth_rate=0.6424424901075522
# ---------------------------------------
# Acetate100_R1 yield=0.09806
# Acetate100_R1 growth_rate=0.3912144045008517
# ---------------------------------------
# Acetate100_R2 yield=0.09279666666666665
# Acetate100_R2 growth_rate=0.31711973535192317
# ---------------------------------------
# Acetate100_R3 yield=0.0884142857142857
# Acetate100_R3 growth_rate=0.4136599140330616
# ---------------------------------------
# Acetate200_R1 yield=0.04789333333333333
# Acetate200_R1 growth_rate=1.0467049118645584
# ---------------------------------------
# Acetate200_R2 yield=0.0483569696969697
# Acetate200_R2 growth_rate=0.3995983761200315
# ---------------------------------------
# Acetate200_R3 yield=0.055877777777777776
# Acetate200_R3 growth_rate=0.4797269340183941
# ---------------------------------------
# DAl10_R1 yield=0.29520777777777774
# DAl10_R1 growth_rate=0.5578065073529842
# ---------------------------------------
# DAl10_R2 yield=0.2587052380952381
# DAl10_R2 growth_rate=0.5036105963798659
# ---------------------------------------
# DAl10_R3 yield=0.31004000000000004
# DAl10_R3 growth_rate=0.5258672488673526
# ---------------------------------------
# DAl100_R1 yield=0.3067026666666667
# DAl100_R1 growth_rate=0.35532412290284215
# ---------------------------------------
# DAl100_R2 yield=0.31589222222222224
# DAl100_R2 growth_rate=0.44896405159571534
# ---------------------------------------
# DAl100_R3 yield=0.34530000000000005
# DAl100_R3 growth_rate=0.35475307482210344
# ---------------------------------------
# DAl200_R1 yield=0.18719904761904763
# DAl200_R1 growth_rate=0.30550719754731115
# ---------------------------------------
# DAl200_R2 yield=0.16935
# DAl200_R2 growth_rate=0.5492446332439018
# ---------------------------------------
# DAl200_R3 yield=0.1558422222222222
# DAl200_R3 growth_rate=0.63026401325321
# ---------------------------------------
# glc0.4_R1 yield=0.8055541025641026
# glc0.4_R1 growth_rate=0.6611649327386537
# ---------------------------------------
# glc0.4_R2 yield=0.6596616216216216
# glc0.4_R2 growth_rate=0.9756113065157014
# ---------------------------------------
# glc0.4_R3 yield=0.6084315384615384
# glc0.4_R3 growth_rate=0.7047293662024647
# ---------------------------------------
# Maltose10_R1 yield=0.6222995238095237
# Maltose10_R1 growth_rate=0.6196613857403798
# ---------------------------------------
# Maltose10_R2 yield=0.6816946666666667
# Maltose10_R2 growth_rate=0.8294864740692602
# ---------------------------------------
# Maltose10_R3 yield=0.6523155555555554
# Maltose10_R3 growth_rate=0.5275006371713307
# ---------------------------------------
# Maltose100_R2 yield=0.472148
# Maltose100_R2 growth_rate=0.5717046597878476
# ---------------------------------------
# Maltose100_R3 yield=0.4652325
# Maltose100_R3 growth_rate=0.5966202064450687
# ---------------------------------------
# Maltose100_R4 yield=0.484714358974359
# Maltose100_R4 growth_rate=0.45541834274466286
# ---------------------------------------
# Maltose200_R1 yield=0.3363252380952381
# Maltose200_R1 growth_rate=0.6075903998109652
# ---------------------------------------
# Maltose200_R2 yield=0.3302298039215687
# Maltose200_R2 growth_rate=0.502408358273475
# ---------------------------------------
# Maltose200_R3 yield=0.32414966666666667
# Maltose200_R3 growth_rate=0.45730115171781077
# ---------------------------------------
# Mannitol10_R1 yield=0.5603941666666666
# Mannitol10_R1 growth_rate=0.5244070325419385
# ---------------------------------------
# Mannitol10_R2 yield=0.5642564444444443
# Mannitol10_R2 growth_rate=0.5238962451510344
# ---------------------------------------
# Mannitol10_R3 yield=0.618520606060606
# Mannitol10_R3 growth_rate=0.623664524910492
# ---------------------------------------
# Mannitol100_R1 yield=0.623494
# Mannitol100_R1 growth_rate=0.686484319733043
# ---------------------------------------
# Mannitol100_R2 yield=0.68082
# Mannitol100_R2 growth_rate=0.5641296512225562
# ---------------------------------------
# Mannitol100_R3 yield=0.6449672727272727
# Mannitol100_R3 growth_rate=0.5628350510932152
# ---------------------------------------
# Mannitol200_R1 yield=0.6030575
# Mannitol200_R1 growth_rate=1.0453138629573382
# ---------------------------------------
# Mannitol200_R2 yield=0.6095233333333333
# Mannitol200_R2 growth_rate=0.858468033632041
# ---------------------------------------
# Mannitol200_R3 yield=0.45442962962962963
# Mannitol200_R3 growth_rate=0.5727181946917276
# ---------------------------------------
# Succinate10_R1 yield=0.20479388888888886
# Succinate10_R1 growth_rate=0.3852537242824158
# ---------------------------------------
# Succinate10_R2 yield=0.24262
# Succinate10_R2 growth_rate=0.6219895892322092
# ---------------------------------------
# Succinate10_R3 yield=0.21631538461538463
# Succinate10_R3 growth_rate=0.4905648981935309
# ---------------------------------------
# Succinate100_R1 yield=0.5235373333333333
# Succinate100_R1 growth_rate=0.6185631229588288
# ---------------------------------------
# Succinate100_R2 yield=0.5116673333333334
# Succinate100_R2 growth_rate=0.3245795578833378
# ---------------------------------------
# Succinate100_R3 yield=0.5228486666666666
# Succinate100_R3 growth_rate=0.3616635776588205
# ---------------------------------------
# Succinate200_R1 yield=0.2778007407407408
# Succinate200_R1 growth_rate=0.4338563600342913
# ---------------------------------------
# Succinate200_R2 yield=0.19799407407407407
# Succinate200_R2 growth_rate=0.35616275961212596
# ---------------------------------------
# Succinate200_R3 yield=0.17523111111111112
# Succinate200_R3 growth_rate=0.3901432346315963
# ---------------------------------------
# xyl10_R1 yield=0.7421079365079364
# xyl10_R1 growth_rate=0.4293840950742531
# ---------------------------------------
# xyl10_R2 yield=0.6821497916666667
# xyl10_R2 growth_rate=0.5252895765700732
# ---------------------------------------
# xyl10_R3 yield=0.6533996396396395
# xyl10_R3 growth_rate=0.5487106087401111
# ---------------------------------------
# xyl100_R1 yield=0.5869949999999999
# xyl100_R1 growth_rate=0.4959248278496891
# ---------------------------------------
# xyl100_R2 yield=0.6357266666666667
# xyl100_R2 growth_rate=0.5004803411747822
# ---------------------------------------
# xyl100_R3 yield=0.6245777777777777
# xyl100_R3 growth_rate=0.4906804494531506
# ---------------------------------------
# xyl200_R1 yield=0.497661981981982
# xyl200_R1 growth_rate=0.4791124227773879
# ---------------------------------------
# xyl200_R2 yield=0.5704826666666667
# xyl200_R2 growth_rate=0.4769113981615147
# ---------------------------------------
# xyl200_R3 yield=0.5534776068376068
# xyl200_R3 growth_rate=0.47028126814943405
# ---------------------------------------
# glc10uL_R1 found negative od  13
# glc10uL_R1 yield=0.18849154471544716
# glc10uL_R1 growth_rate=1.9278578823521997
# ---------------------------------------
# glc10uL_R2 yield=0.18859166666666666
# glc10uL_R2 growth_rate=1.33439594848979
# ---------------------------------------
# glc10uL_R3 found negative od  16
# glc10uL_R3 yield=0.15685882352941175
# glc10uL_R3 growth_rate=2.1649853568926947
# ---------------------------------------
# glc10uL_R4 yield=0.16417777777777776
# glc10uL_R4 growth_rate=1.5979752762537027
# ---------------------------------------
# glc10uL_R5 found negative od  7
# glc10uL_R5 yield=0.18595571428571428
# glc10uL_R5 growth_rate=2.221359613431257
# ---------------------------------------
# glc100uL_R1 found negative od  21
# glc100uL_R1 yield=0.4971432520325203
# glc100uL_R1 growth_rate=2.01853009056958
# ---------------------------------------
# glc100uL_R2 yield=0.5602819753086419
# glc100uL_R2 growth_rate=2.2854448862471024
# ---------------------------------------
# glc100uL_R3 found negative od  22
# glc100uL_R3 yield=0.5608944444444445
# glc100uL_R3 growth_rate=1.2976370310512721
# ---------------------------------------
# glc100uL_R4 yield=0.5374426666666667
# glc100uL_R4 growth_rate=1.3153155796714104
# ---------------------------------------
# glc100uL_R5 found negative od  25
# glc100uL_R5 yield=0.575143111111111
# glc100uL_R5 growth_rate=0.5031844919225671
# ---------------------------------------
# glc20uL_R1 found negative od  15
# glc20uL_R1 yield=0.29588400000000004
# glc20uL_R1 growth_rate=1.9722818922914436
# ---------------------------------------
# glc20uL_R2 yield=0.29475450980392154
# glc20uL_R2 growth_rate=1.3388804250370974
# ---------------------------------------
# glc20uL_R3 found negative od  17
# glc20uL_R3 yield=0.2696186666666666
# glc20uL_R3 growth_rate=2.267434508543929
# ---------------------------------------
# glc20uL_R4 yield=0.24626245614035083
# glc20uL_R4 growth_rate=1.5089237424149595
# ---------------------------------------
# glc20uL_R5 found negative od  8
# glc20uL_R5 yield=0.2552937254901961
# glc20uL_R5 growth_rate=2.0422334996541656
# ---------------------------------------
# glc30uL_R1 found negative od  16
# glc30uL_R1 yield=0.38745125
# glc30uL_R1 growth_rate=1.692905363212009
# ---------------------------------------
# glc30uL_R2 yield=0.32048385964912285
# glc30uL_R2 growth_rate=1.210510405239305
# ---------------------------------------
# glc30uL_R3 found negative od  12
# glc30uL_R3 yield=0.3323009523809524
# glc30uL_R3 growth_rate=1.7795589063161188
# ---------------------------------------
# glc30uL_R4 yield=0.4156793333333334
# glc30uL_R4 growth_rate=0.9649745803471245
# ---------------------------------------
# glc30uL_R5 found negative od  21
# glc30uL_R5 yield=0.3197933333333334
# glc30uL_R5 growth_rate=2.188920883696878
# ---------------------------------------
# glc40uL_R1 found negative od  16
# glc40uL_R1 yield=0.4515870370370371
# glc40uL_R1 growth_rate=1.5719188083411253
# ---------------------------------------
# glc40uL_R2 yield=0.3916882352941176
# glc40uL_R2 growth_rate=1.1810820927239938
# ---------------------------------------
# glc40uL_R3 found negative od  13
# glc40uL_R3 yield=0.3681633333333334
# glc40uL_R3 growth_rate=1.6216337161972092
# ---------------------------------------
# glc40uL_R4 yield=0.39650428571428575
# glc40uL_R4 growth_rate=1.1776850768240752
# ---------------------------------------
# glc40uL_R5 found negative od  16
# glc40uL_R5 yield=0.35352245614035094
# glc40uL_R5 growth_rate=2.00825897748927
# ---------------------------------------
# glc50uL_R1 found negative od  18
# glc50uL_R1 yield=0.5013726666666666
# glc50uL_R1 growth_rate=1.5880526933820696
# ---------------------------------------
# glc50uL_R2 yield=0.4594423529411764
# glc50uL_R2 growth_rate=1.1553204352560502
# ---------------------------------------
# glc50uL_R3 found negative od  17
# glc50uL_R3 yield=0.45537466666666665
# glc50uL_R3 growth_rate=1.7811478799069795
# ---------------------------------------
# glc50uL_R4 yield=0.4134225
# glc50uL_R4 growth_rate=1.2473209290056184
# ---------------------------------------
# glc50uL_R5 found negative od  18
# glc50uL_R5 yield=0.4167466666666667
# glc50uL_R5 growth_rate=1.825616104021122
# ---------------------------------------
# glc60uL_R1 found negative od  18
# glc60uL_R1 yield=0.4821940350877193
# glc60uL_R1 growth_rate=1.5656026826593752
# ---------------------------------------
# glc60uL_R2 yield=0.473879595959596
# glc60uL_R2 growth_rate=1.064765195138738
# ---------------------------------------
# glc60uL_R3 found negative od  14
# glc60uL_R3 yield=0.43234740740740746
# glc60uL_R3 growth_rate=1.5842650063742256
# ---------------------------------------
# glc60uL_R4 yield=0.4579004166666667
# glc60uL_R4 growth_rate=1.2647749618431083
# ---------------------------------------
# glc60uL_R5 found negative od  23
# glc60uL_R5 yield=0.4580314285714286
# glc60uL_R5 growth_rate=0.5633098386345288
# ---------------------------------------
# glc70uL_R1 found negative od  12
# glc70uL_R1 yield=0.5172917460317461
# glc70uL_R1 growth_rate=1.3769942274368978
# ---------------------------------------
# glc70uL_R2 yield=0.5284445614035086
# glc70uL_R2 growth_rate=1.0239548130943823
# ---------------------------------------
# glc70uL_R3 found negative od  15
# glc70uL_R3 yield=0.4790063636363637
# glc70uL_R3 growth_rate=1.4818362963686924
# ---------------------------------------
# glc70uL_R4 yield=0.500853
# glc70uL_R4 growth_rate=1.0171774996691667
# ---------------------------------------
# glc70uL_R5 found negative od  23
# glc70uL_R5 yield=0.4587336231884058
# glc70uL_R5 growth_rate=0.40571149174406684
# ---------------------------------------
# glc80uL_R1 found negative od  20
# glc80uL_R1 yield=0.5230422222222221
# glc80uL_R1 growth_rate=1.3128430168080227
# ---------------------------------------
# glc80uL_R2 yield=0.46199087719298254
# glc80uL_R2 growth_rate=1.1434589377006714
# ---------------------------------------
# glc80uL_R3 found negative od  16
# glc80uL_R3 yield=0.4772670370370371
# glc80uL_R3 growth_rate=1.4692722134843308
# ---------------------------------------
# glc80uL_R4 yield=0.4598960784313726
# glc80uL_R4 growth_rate=1.2151700632463185
# ---------------------------------------
# glc80uL_R5 found negative od  21
# glc80uL_R5 yield=0.4934844444444445
# glc80uL_R5 growth_rate=0.6831154745061071
# ---------------------------------------
# glc90uL_R1 found negative od  6
# glc90uL_R1 yield=0.4901553153153153
# glc90uL_R1 growth_rate=4.763619542217351
# ---------------------------------------
# glc90uL_R2 yield=0.5281161904761904
# glc90uL_R2 growth_rate=1.1756502203310488
# ---------------------------------------
# glc90uL_R3 found negative od  20
# glc90uL_R3 yield=0.5278826666666666
# glc90uL_R3 growth_rate=0.9541497962797528
# ---------------------------------------
# glc90uL_R4 yield=0.4833256140350878
# glc90uL_R4 growth_rate=1.2011107017774172
# ---------------------------------------
# glc90uL_R5 found negative od  16
# glc90uL_R5 yield=0.4749298039215686
# glc90uL_R5 growth_rate=1.5561127066539866
# ---------------------------------------
# galactose10_R1 yield=0.6879276190476189
# galactose10_R1 growth_rate=0.4481497156654729
# ---------------------------------------
# galactose10_R2 yield=0.6222
# galactose10_R2 growth_rate=0.44258423736333397
# ---------------------------------------
# galactose10_R3 yield=0.6780866666666667
# galactose10_R3 growth_rate=0.5244082009632876
# ---------------------------------------
# galactose100_R1 found negative od  9
# galactose100_R1 yield=0.7158698765432099
# galactose100_R1 growth_rate=0.5205687436961994
# ---------------------------------------
# galactose100_R2 yield=0.711353846153846
# galactose100_R2 growth_rate=0.48067305080446826
# ---------------------------------------
# galactose100_R3 yield=0.6682333333333332
# galactose100_R3 growth_rate=0.5342806822205822
# ---------------------------------------
# galactose200_R1 found negative od  16
# galactose200_R1 yield=0.5483732203389831
# galactose200_R1 growth_rate=0.6573246861377566
# ---------------------------------------
# galactose200_R2 found negative od  14
# galactose200_R2 yield=0.5311728682170542
# galactose200_R2 growth_rate=0.5972411377108288
# ---------------------------------------
# galactose200_R3 found negative od  13
# galactose200_R3 yield=0.5152842276422764
# galactose200_R3 growth_rate=0.6322881602799183
# ---------------------------------------
# glc0.4_R1 yield=0.6387266666666667
# glc0.4_R1 growth_rate=0.690712187696553
# ---------------------------------------
# glc0.4_R2 yield=0.7151635555555553
# glc0.4_R2 growth_rate=0.801142908401337
# ---------------------------------------
# glc0.4_R3 yield=0.6591644444444444
# glc0.4_R3 growth_rate=0.712264723060383
# ---------------------------------------
# LAlanine10_R1 yield=0.22809536231884053
# LAlanine10_R1 growth_rate=0.3336621612122833
# ---------------------------------------
# LAlanine10_R2 yield=0.2359511111111111
# LAlanine10_R2 growth_rate=0.3736953576978851
# ---------------------------------------
# LAlanine10_R3 yield=0.24359958333333334
# LAlanine10_R3 growth_rate=0.2913577089502171
# ---------------------------------------
# LAlanine100_R1 yield=0.3073366666666667
# LAlanine100_R1 growth_rate=0.31933641815715624
# ---------------------------------------
# LAlanine100_R2 yield=0.311527619047619
# LAlanine100_R2 growth_rate=0.30418159438937153
# ---------------------------------------
# LAlanine100_R3 yield=0.3186811111111112
# LAlanine100_R3 growth_rate=0.39422815904371145
# ---------------------------------------
# LAlanine200_R1 yield=0.16779333333333332
# LAlanine200_R1 growth_rate=0.3242407648821933
# ---------------------------------------
# LAlanine200_R2 yield=0.2605688888888889
# LAlanine200_R2 growth_rate=0.9992565039183152
# ---------------------------------------
# LAlanine200_R3 yield=0.2446166666666667
# LAlanine200_R3 growth_rate=0.6312937128365153
# ---------------------------------------
# pyruvate10_R1 yield=0.2264519298245614
# pyruvate10_R1 growth_rate=0.4475193314000852
# ---------------------------------------
# pyruvate10_R2 yield=0.21473684210526311
# pyruvate10_R2 growth_rate=0.3488316685628732
# ---------------------------------------
# pyruvate10_R3 yield=0.24856158730158726
# pyruvate10_R3 growth_rate=0.4438970932521709
# ---------------------------------------
# pyruvate100_R1 yield=0.7211783333333333
# pyruvate100_R1 growth_rate=0.3502926022695702
# ---------------------------------------
# pyruvate100_R2 yield=0.7354266666666666
# pyruvate100_R2 growth_rate=0.43562294815170405
# ---------------------------------------
# pyruvate100_R3 yield=0.7406922222222222
# pyruvate100_R3 growth_rate=0.4174665155781041
# ---------------------------------------
# pyruvate200_R1 yield=0.36723333333333336
# pyruvate200_R1 growth_rate=0.37359761515539974
# ---------------------------------------
# pyruvate200_R2 yield=0.2823238888888889
# pyruvate200_R2 growth_rate=0.5207135358534603
# ---------------------------------------
# pyruvate200_R3 yield=0.16074499999999997
# pyruvate200_R3 growth_rate=0.4271165687755039
# ---------------------------------------
# Ribose10_R1 yield=0.34074444444444446
# Ribose10_R1 growth_rate=0.4263062517648974
# ---------------------------------------
# Ribose10_R2 yield=0.3471369696969696
# Ribose10_R2 growth_rate=0.5641129693984318
# ---------------------------------------
# Ribose10_R3 yield=0.3468880952380952
# Ribose10_R3 growth_rate=0.45457703398874927
# ---------------------------------------
# Ribose100_R1 yield=0.5597005333333332
# Ribose100_R1 growth_rate=0.5033036192240455
# ---------------------------------------
# Ribose100_R2 yield=0.5612058974358974
# Ribose100_R2 growth_rate=0.5358932155090103
# ---------------------------------------
# Ribose100_R3 yield=0.5669485333333333
# Ribose100_R3 growth_rate=0.4713838118229243
# ---------------------------------------
# Ribose200_R1 yield=0.6507954166666666
# Ribose200_R1 growth_rate=0.48127880013846314
# ---------------------------------------
# Ribose200_R2 yield=0.6497214285714286
# Ribose200_R2 growth_rate=0.44058230146296345
# ---------------------------------------
# Ribose200_R3 yield=0.6551792592592592
# Ribose200_R3 growth_rate=0.357853581761032
# ---------------------------------------
# Sorbitol10_R1 yield=0.6441266666666666
# Sorbitol10_R1 growth_rate=0.40357633418928696
# ---------------------------------------
# Sorbitol10_R2 yield=0.6322479166666667
# Sorbitol10_R2 growth_rate=0.3981004796905881
# ---------------------------------------
# Sorbitol10_R3 yield=0.3803823333333334
# Sorbitol10_R3 growth_rate=0.42317919608657123
# ---------------------------------------
# Sorbitol100_R1 yield=0.6554581481481481
# Sorbitol100_R1 growth_rate=0.40960005156479296
# ---------------------------------------
# Sorbitol100_R2 yield=0.5981079166666666
# Sorbitol100_R2 growth_rate=0.4104200854362717
# ---------------------------------------
# Sorbitol100_R3 yield=0.49809777777777775
# Sorbitol100_R3 growth_rate=0.41589318482497634
# ---------------------------------------
# Sorbitol200_R1 yield=0.52357
# Sorbitol200_R1 growth_rate=0.44844285923634797
# ---------------------------------------
# Sorbitol200_R2 yield=0.5298006060606061
# Sorbitol200_R2 growth_rate=0.4415642268771481
# ---------------------------------------
# Sorbitol200_R3 yield=0.5316842424242423
# Sorbitol200_R3 growth_rate=0.4481000701330169
# ---------------------------------------
# uridine10_R1 yield=0.14024583333333335
# uridine10_R1 growth_rate=0.37236897985404227
# ---------------------------------------
# uridine10_R2 yield=0.14992190476190473
# uridine10_R2 growth_rate=0.4588607521475678
# ---------------------------------------
# uridine10_R3 yield=0.13604380952380954
# uridine10_R3 growth_rate=0.5244076267647259
# ---------------------------------------
# uridine100_R1 yield=0.15468285714285712
# uridine100_R1 growth_rate=0.346676414626632
# ---------------------------------------
# uridine100_R2 yield=0.1343438095238095
# uridine100_R2 growth_rate=0.3726830200423116
# ---------------------------------------
# uridine100_R3 yield=0.16363333333333333
# uridine100_R3 growth_rate=0.3796908748143187
# ---------------------------------------
# uridine200_R1 yield=0.09860148148148146
# uridine200_R1 growth_rate=0.40218612407980203
# ---------------------------------------
# uridine200_R2 yield=0.09908666666666667
# uridine200_R2 growth_rate=0.23267478287243373
# ---------------------------------------
# uridine200_R3 yield=0.09290133333333332
# uridine200_R3 growth_rate=0.3530335378841698
# ---------------------------------------
# Fru10_R1 yield=0.5916855555555555
# Fru10_R1 growth_rate=0.5925531080326477
# ---------------------------------------
# Fru10_R2 yield=0.6085788888888888
# Fru10_R2 growth_rate=0.538126158613446
# ---------------------------------------
# Fru10_R3 yield=0.6196177777777777
# Fru10_R3 growth_rate=0.5895420990905142
# ---------------------------------------
# Fru100_R1 yield=0.6776466666666666
# Fru100_R1 growth_rate=0.46377372840538383
# ---------------------------------------
# Fru100_R2 yield=0.6140166666666667
# Fru100_R2 growth_rate=0.5926601355076545
# ---------------------------------------
# Fru100_R3 yield=0.5767183333333332
# Fru100_R3 growth_rate=0.4318162142561027
# ---------------------------------------
# Fru200_R1 yield=0.48379878787878794
# Fru200_R1 growth_rate=0.5657791284982066
# ---------------------------------------
# Fru200_R2 yield=0.5128166666666666
# Fru200_R2 growth_rate=0.5721044922086175
# ---------------------------------------
# Fru200_R3 yield=0.5206051851851852
# Fru200_R3 growth_rate=0.5291949714337161
# ---------------------------------------
# Fum10_R1 yield=0.44661500000000004
# Fum10_R1 growth_rate=0.4072470099877906
# ---------------------------------------
# Fum10_R2 yield=0.4429133333333333
# Fum10_R2 growth_rate=0.36728643930299354
# ---------------------------------------
# Fum10_R3 yield=0.47206444444444445
# Fum10_R3 growth_rate=0.39584059152791984
# ---------------------------------------
# Fum100_R1 yield=0.15691666666666665
# Fum100_R1 growth_rate=1.5249886642957127
# ---------------------------------------
# Fum100_R2 yield=0.17738666666666666
# Fum100_R2 growth_rate=0.8432361148639753
# ---------------------------------------
# Fum100_R3 yield=0.16310666666666665
# Fum100_R3 growth_rate=1.013243638669858
# ---------------------------------------
# Fum200_R1 yield=0.022612549019607842
# Fum200_R1 growth_rate=0.24968814003386258
# ---------------------------------------
# Fum200_R2 yield=1.2355
# Fum200_R2 growth_rate=3.3219687631072152
# ---------------------------------------
# Fum200_R3 yield=0.026977272727272728
# Fum200_R3 growth_rate=0.3261027354280725
# ---------------------------------------
# Glc0.4_R1 yield=0.49270011111111117
# Glc0.4_R1 growth_rate=0.716550366615786
# ---------------------------------------
# Glc0.4_R2 yield=0.7795688172043009
# Glc0.4_R2 growth_rate=0.5989442305202827
# ---------------------------------------
# Glc0.4_R3 yield=0.7658755555555555
# Glc0.4_R3 growth_rate=0.7430534063744074
# ---------------------------------------
# Glu10_R1 yield=0.4420490196078432
# Glu10_R1 growth_rate=0.5479645754511077
# ---------------------------------------
# Glu10_R2 yield=0.4330478431372549
# Glu10_R2 growth_rate=0.9402927163669267
# ---------------------------------------
# Glu10_R3 yield=0.4752871794871796
# Glu10_R3 growth_rate=0.5198613444962646
# ---------------------------------------
# Glu100_R1 yield=0.7760707692307693
# Glu100_R1 growth_rate=0.5203065705862616
# ---------------------------------------
# Glu100_R2 yield=0.7565368888888888
# Glu100_R2 growth_rate=0.5301382454852971
# ---------------------------------------
# Glu100_R3 yield=0.7499090476190474
# Glu100_R3 growth_rate=0.6521003670773952
# ---------------------------------------
# Glu200_R1 yield=0.6495763888888889
# Glu200_R1 growth_rate=0.8685097565100582
# ---------------------------------------
# Glu200_R2 yield=0.6536445333333333
# Glu200_R2 growth_rate=0.9230092827042871
# ---------------------------------------
# Glu200_R3 yield=0.6548485416666666
# Glu200_R3 growth_rate=1.095122031188896
# ---------------------------------------
# Gly10_R1 yield=0.4209630000000001
# Gly10_R1 growth_rate=0.5911448368261545
# ---------------------------------------
# Gly10_R2 yield=0.404071282051282
# Gly10_R2 growth_rate=0.5820886413023176
# ---------------------------------------
# Gly10_R3 yield=0.40440358974358975
# Gly10_R3 growth_rate=0.5984329732890089
# ---------------------------------------
# Gly100_R1 yield=0.5619206451612903
# Gly100_R1 growth_rate=0.36592894738618986
# ---------------------------------------
# Gly100_R2 yield=0.503052761904762
# Gly100_R2 growth_rate=0.32961759851957934
# ---------------------------------------
# Gly100_R3 yield=0.583627619047619
# Gly100_R3 growth_rate=0.36865645448218937
# ---------------------------------------
# Gly200_R1 yield=0.4599745977011494
# Gly200_R1 growth_rate=0.4148509595201524
# ---------------------------------------
# Gly200_R2 yield=0.4943620238095239
# Gly200_R2 growth_rate=0.5228641552299544
# ---------------------------------------
# Gly200_R3 yield=0.5138586206896553
# Gly200_R3 growth_rate=0.4283724041687709
# ---------------------------------------
# pro10_R1 yield=0.04512055555555555
# pro10_R1 growth_rate=0.29291744823389815
# ---------------------------------------
# pro10_R2 yield=0.041959393939393935
# pro10_R2 growth_rate=0.2354951823316
# ---------------------------------------
# pro10_R3 yield=0.03849533333333334
# pro10_R3 growth_rate=0.2680881486995313
# ---------------------------------------
# pro100_R1 yield=0.027659629629629628
# pro100_R1 growth_rate=0.21248046138500995
# ---------------------------------------
# pro100_R2 yield=0.026131515151515152
# pro100_R2 growth_rate=0.26140674084564286
# ---------------------------------------
# pro100_R3 yield=0.028797499999999997
# pro100_R3 growth_rate=0.326151277574973
# ---------------------------------------
# pro200_R1 yield=0.03726866666666667
# pro200_R1 growth_rate=0.8375565773154757
# ---------------------------------------
# pro200_R2 yield=0.043609999999999996
# pro200_R2 growth_rate=0.41445606088397663
# ---------------------------------------
# pro200_R3 yield=0.043911851851851855
# pro200_R3 growth_rate=0.41804950206406044
# ---------------------------------------
# tre0_R1 yield=0.5727866666666667
# tre0_R1 growth_rate=0.4459057517359965
# ---------------------------------------
# tre0_R2 yield=0.5617090909090908
# tre0_R2 growth_rate=0.5319176531089229
# ---------------------------------------
# tre0_R3 yield=0.5719138888888888
# tre0_R3 growth_rate=0.5217199589521507
# ---------------------------------------
# tre00_R1 yield=0.38493272727272737
# tre00_R1 growth_rate=0.6356169577132649
# ---------------------------------------
# tre00_R2 yield=0.39818533333333334
# tre00_R2 growth_rate=0.41041858285170607
# ---------------------------------------
# tre00_R3 yield=0.39431151515151514
# tre00_R3 growth_rate=0.7099363261303339
# ---------------------------------------
# tre00_R1.1 yield=0.2913537777777778
# tre00_R1.1 growth_rate=0.494137240508314
# ---------------------------------------
# tre00_R2.1 yield=0.2978112820512821
# tre00_R2.1 growth_rate=0.5948596950836835
# ---------------------------------------
# tre00_R3.1 yield=0.31591925925925923
# tre00_R3.1 growth_rate=0.7661945789627388
# ---------------------------------------
# DSerine10_R1 yield=0.28952818181818185
# DSerine10_R1 growth_rate=0.6226787841841951
# ---------------------------------------
# DSerine10_R2 yield=0.3287773333333333
# DSerine10_R2 growth_rate=0.4685660786630112
# ---------------------------------------
# DSerine10_R3 yield=0.3013456140350877
# DSerine10_R3 growth_rate=0.6041388357645241
# ---------------------------------------
# DSerine25_R1 yield=0.4081349019607843
# DSerine25_R1 growth_rate=0.4497877940236919
# ---------------------------------------
# DSerine25_R2 yield=0.39408487179487184
# DSerine25_R2 growth_rate=0.5776315000891497
# ---------------------------------------
# DSerine25_R3 yield=0.3943616352201258
# DSerine25_R3 growth_rate=0.437959360344258
# ---------------------------------------
# DSerine5_R1 yield=0.12316948717948716
# DSerine5_R1 growth_rate=0.5708233666215758
# ---------------------------------------
# DSerine5_R2 yield=0.16669444444444445
# DSerine5_R2 growth_rate=0.4877730680288503
# ---------------------------------------
# DSerine5_R3 yield=0.1158774074074074
# DSerine5_R3 growth_rate=0.5130479971156432
# ---------------------------------------
# glc0.4_R1 yield=0.5536220370370369
# glc0.4_R1 growth_rate=0.6292367608326559
# ---------------------------------------
# glc0.4_R2 yield=0.5950533333333334
# glc0.4_R2 growth_rate=0.7288212290888735
# ---------------------------------------
# glc0.4_R3 yield=0.5910376470588234
# glc0.4_R3 growth_rate=0.755871928957204
# ---------------------------------------
# GlycylAspartic10_R1 yield=0.031203589743589742
# GlycylAspartic10_R1 growth_rate=0.4661547357405473
# ---------------------------------------
# GlycylAspartic10_R2 yield=0.03121666666666667
# GlycylAspartic10_R2 growth_rate=0.3015041197085504
# ---------------------------------------
# GlycylAspartic10_R3 yield=0.03384606060606061
# GlycylAspartic10_R3 growth_rate=0.3307730990942652
# ---------------------------------------
# GlycylAspartic25_R1 yield=0.04262166666666666
# GlycylAspartic25_R1 growth_rate=0.6005874227703923
# ---------------------------------------
# GlycylAspartic25_R2 yield=0.044684999999999996
# GlycylAspartic25_R2 growth_rate=0.4039079319291401
# ---------------------------------------
# GlycylAspartic25_R3 yield=0.04306074074074075
# GlycylAspartic25_R3 growth_rate=0.44328110218795946
# ---------------------------------------
# GlycylAspartic5_R1 yield=0.02442916666666667
# GlycylAspartic5_R1 growth_rate=0.5372360632415686
# ---------------------------------------
# GlycylAspartic5_R2 yield=0.023597849462365598
# GlycylAspartic5_R2 growth_rate=0.17768037125302866
# ---------------------------------------
# GlycylAspartic5_R3 yield=0.024320533333333335
# GlycylAspartic5_R3 growth_rate=0.49132792715419693
# ---------------------------------------
# Ketoglutarate10_R1 yield=0.35042222222222225
# Ketoglutarate10_R1 growth_rate=1.1120491315893113
# ---------------------------------------
# Ketoglutarate10_R2 yield=0.33174380952380955
# Ketoglutarate10_R2 growth_rate=1.0694334421760143
# ---------------------------------------
# Ketoglutarate10_R3 yield=0.3534066666666667
# Ketoglutarate10_R3 growth_rate=0.4604159513661958
# ---------------------------------------
# Ketoglutarate15_R1 yield=0.45029066666666673
# Ketoglutarate15_R1 growth_rate=0.47622872709456743
# ---------------------------------------
# Ketoglutarate15_R2 yield=0.5203226666666666
# Ketoglutarate15_R2 growth_rate=0.4805904127094215
# ---------------------------------------
# Ketoglutarate15_R3 yield=0.5788788888888888
# Ketoglutarate15_R3 growth_rate=0.3796983979779566
# ---------------------------------------
# Ketoglutarate5_R1 yield=0.17619787878787876
# Ketoglutarate5_R1 growth_rate=4.839148044317873
# ---------------------------------------
# Ketoglutarate5_R2 yield=0.1806514814814815
# Ketoglutarate5_R2 growth_rate=0.9860516742751824
# ---------------------------------------
# Ketoglutarate5_R3 yield=0.19547083333333332
# Ketoglutarate5_R3 growth_rate=1.359563386869774
# ---------------------------------------
# Lasparagine10_R1 yield=0.03202270833333334
# Lasparagine10_R1 growth_rate=0.6815830517959535
# ---------------------------------------
# Lasparagine10_R2 yield=0.03157454545454545
# Lasparagine10_R2 growth_rate=0.24577416867728383
# ---------------------------------------
# Lasparagine10_R3 yield=0.031606666666666665
# Lasparagine10_R3 growth_rate=0.22830620729563467
# ---------------------------------------
# Lasparagine25_R1 yield=0.041113333333333335
# Lasparagine25_R1 growth_rate=0.4130657245122129
# ---------------------------------------
# Lasparagine25_R2 yield=0.04222962962962963
# Lasparagine25_R2 growth_rate=0.2702744315893044
# ---------------------------------------
# Lasparagine25_R3 yield=0.041575999999999995
# Lasparagine25_R3 growth_rate=0.5091448532816655
# ---------------------------------------
# Lasparagine5_R1 yield=0.022604133333333328
# Lasparagine5_R1 growth_rate=1.0237734302442258
# ---------------------------------------
# Lasparagine5_R2 yield=0.02344949494949495
# Lasparagine5_R2 growth_rate=1.012710330454772
# ---------------------------------------
# Lasparagine5_R3 yield=0.02152828282828283
# Lasparagine5_R3 growth_rate=0.7927628142100345
# ---------------------------------------
# Laspartic10_R1 yield=0.032334609929078016
# Laspartic10_R1 growth_rate=0.5711920066014439
# ---------------------------------------
# Laspartic10_R2 yield=0.031275254237288136
# Laspartic10_R2 growth_rate=0.35841909325743754
# ---------------------------------------
# Laspartic10_R3 yield=0.033946111111111114
# Laspartic10_R3 growth_rate=0.47152975044234163
# ---------------------------------------
# Laspartic25_R1 yield=0.036028484848484844
# Laspartic25_R1 growth_rate=0.3036608335397637
# ---------------------------------------
# Laspartic25_R2 yield=0.03893
# Laspartic25_R2 growth_rate=0.2501818310883783
# ---------------------------------------
# Laspartic25_R3 yield=0.03969875
# Laspartic25_R3 growth_rate=0.3194143698704272
# ---------------------------------------
# Laspartic5_R1 yield=0.02283931623931624
# Laspartic5_R1 growth_rate=0.24439841353055208
# ---------------------------------------
# Laspartic5_R2 yield=0.02267024154589372
# Laspartic5_R2 growth_rate=0.4165932896266986
# ---------------------------------------
# Laspartic5_R3 yield=0.020855652173913043
# Laspartic5_R3 growth_rate=0.22975802875310028
# ---------------------------------------
# Tartaric10_R1 yield=0.03260567901234568
# Tartaric10_R1 growth_rate=0.3260128776364544
# ---------------------------------------
# Tartaric10_R2 yield=0.03459282051282051
# Tartaric10_R2 growth_rate=0.3634477324006553
# ---------------------------------------
# Tartaric10_R3 yield=0.033075238095238095
# Tartaric10_R3 growth_rate=0.39827617010167404
# ---------------------------------------
# Tartaric25_R1 yield=0.0346516049382716
# Tartaric25_R1 growth_rate=0.29555722301552695
# ---------------------------------------
# Tartaric25_R2 yield=0.03346238095238095
# Tartaric25_R2 growth_rate=0.3545954816193106
# ---------------------------------------
# Tartaric25_R3 yield=0.03251843137254903
# Tartaric25_R3 growth_rate=0.3203032602400116
# ---------------------------------------
# Tartaric5_R1 yield=0.03404233333333333
# Tartaric5_R1 growth_rate=0.38643455874663907
# ---------------------------------------
# Tartaric5_R2 yield=0.030956318407960197
# Tartaric5_R2 growth_rate=0.5542571732121285
# ---------------------------------------
# Tartaric5_R3 yield=0.029739285714285708
# Tartaric5_R3 growth_rate=0.543575621884244
# ---------------------------------------
# Deoxyadenosine1.2_R1 yield=0.02870820512820513
# Deoxyadenosine1.2_R1 growth_rate=0.24442578130983653
# ---------------------------------------
# Deoxyadenosine1.2_R2 yield=0.02552985507246377
# Deoxyadenosine1.2_R2 growth_rate=0.31840541044814547
# ---------------------------------------
# Deoxyadenosine1.2_R3 yield=0.025198222222222223
# Deoxyadenosine1.2_R3 growth_rate=0.18535006332669943
# ---------------------------------------
# Deoxyadenosine12_R1 yield=0.060356969696969694
# Deoxyadenosine12_R1 growth_rate=0.33176348909044456
# ---------------------------------------
# Deoxyadenosine12_R2 yield=0.05819030303030303
# Deoxyadenosine12_R2 growth_rate=0.32991770972441775
# ---------------------------------------
# Deoxyadenosine12_R3 yield=0.07056296296296297
# Deoxyadenosine12_R3 growth_rate=0.282769289675786
# ---------------------------------------
# Deoxyadenosine24_R1 yield=0.11817777777777777
# Deoxyadenosine24_R1 growth_rate=0.3436163410967374
# ---------------------------------------
# Deoxyadenosine24_R2 yield=0.22103555555555554
# Deoxyadenosine24_R2 growth_rate=0.46399434441371956
# ---------------------------------------
# Deoxyadenosine24_R3 yield=0.2337043137254902
# Deoxyadenosine24_R3 growth_rate=0.3839984222538033
# ---------------------------------------
# Dglucosamine10_R1 yield=0.9262037037037038
# Dglucosamine10_R1 growth_rate=0.4873416234174396
# ---------------------------------------
# Dglucosamine10_R2 yield=0.8806146666666665
# Dglucosamine10_R2 growth_rate=0.4347875599453727
# ---------------------------------------
# Dglucosamine10_R3 yield=0.8385342857142858
# Dglucosamine10_R3 growth_rate=0.4271778150161877
# ---------------------------------------
# Dglucosamine100_R1 yield=0.8560883333333332
# Dglucosamine100_R1 growth_rate=0.42181010786776696
# ---------------------------------------
# Dglucosamine100_R2 yield=0.8221857142857143
# Dglucosamine100_R2 growth_rate=0.4155415910114195
# ---------------------------------------
# Dglucosamine100_R3 yield=0.8310122222222222
# Dglucosamine100_R3 growth_rate=0.40656427322712846
# ---------------------------------------
# Dglucosamine200_R1 yield=0.47241073170731707
# Dglucosamine200_R1 growth_rate=0.43917284845007537
# ---------------------------------------
# Dglucosamine200_R2 yield=0.5056066666666666
# Dglucosamine200_R2 growth_rate=0.40334446619493486
# ---------------------------------------
# Dglucosamine200_R3 yield=0.5128950724637682
# Dglucosamine200_R3 growth_rate=0.3837127454462129
# ---------------------------------------
# dulcitol10_R1 yield=0.1969911111111111
# dulcitol10_R1 growth_rate=0.7286066005525775
# ---------------------------------------
# dulcitol10_R2 yield=0.18884333333333336
# dulcitol10_R2 growth_rate=0.8217474655598441
# ---------------------------------------
# dulcitol10_R3 yield=0.194969696969697
# dulcitol10_R3 growth_rate=0.3602713040491337
# ---------------------------------------
# dulcitol5_R1 yield=0.18960352941176473
# dulcitol5_R1 growth_rate=0.4290463622015744
# ---------------------------------------
# dulcitol5_R2 yield=0.1940411764705882
# dulcitol5_R2 growth_rate=0.7722698544213876
# ---------------------------------------
# dulcitol5_R3 yield=0.18530777777777777
# dulcitol5_R3 growth_rate=1.0339158801241772
# ---------------------------------------
# dulcitol50_R1 yield=0.21013777777777776
# dulcitol50_R1 growth_rate=1.9004189961985696
# ---------------------------------------
# dulcitol50_R2 yield=0.22466484848484847
# dulcitol50_R2 growth_rate=0.7817983551032134
# ---------------------------------------
# dulcitol50_R3 yield=0.1897444444444444
# dulcitol50_R3 growth_rate=0.8531639034449674
# ---------------------------------------
# glc0.4_R1 yield=0.8716666666666666
# glc0.4_R1 growth_rate=0.706352798421108
# ---------------------------------------
# glc0.4_R2 found negative od  8
# glc0.4_R2 yield=0.8413566666666666
# glc0.4_R2 growth_rate=0.8071447014306758
# ---------------------------------------
# glc0.4_R3 yield=0.6138088888888888
# glc0.4_R3 growth_rate=0.7298595301936636
# ---------------------------------------
# Inosine0.8_R1 yield=0.06366190476190475
# Inosine0.8_R1 growth_rate=0.4581393648501098
# ---------------------------------------
# Inosine0.8_R2 yield=0.06002222222222222
# Inosine0.8_R2 growth_rate=0.4347498242165914
# ---------------------------------------
# Inosine0.8_R3 yield=0.06097185185185186
# Inosine0.8_R3 growth_rate=0.38258606686670016
# ---------------------------------------
# Inosine16_R1 yield=0.24483888888888886
# Inosine16_R1 growth_rate=0.4607808938745421
# ---------------------------------------
# Inosine16_R2 yield=0.21765238095238093
# Inosine16_R2 growth_rate=0.31635581900267795
# ---------------------------------------
# Inosine16_R3 yield=0.22718000000000002
# Inosine16_R3 growth_rate=0.3524133942441339
# ---------------------------------------
# Inosine8_R1 yield=0.1883975
# Inosine8_R1 growth_rate=0.40407302181552274
# ---------------------------------------
# Inosine8_R2 yield=0.19562333333333332
# Inosine8_R2 growth_rate=0.871905759667901
# ---------------------------------------
# Inosine8_R3 yield=0.17738333333333334
# Inosine8_R3 growth_rate=0.3666190726901049
# ---------------------------------------
# propionate10_R1 yield=0.04054549019607843
# propionate10_R1 growth_rate=0.20885600893932926
# ---------------------------------------
# propionate10_R2 yield=0.046161999999999995
# propionate10_R2 growth_rate=0.275640374417841
# ---------------------------------------
# propionate10_R3 yield=0.05243000000000001
# propionate10_R3 growth_rate=0.29090626323147967
# ---------------------------------------
# propionate100_R1 yield=0.03333555555555555
# propionate100_R1 growth_rate=0.43027719711778617
# ---------------------------------------
# propionate100_R2 yield=0.036065925925925925
# propionate100_R2 growth_rate=0.21316749513233407
# ---------------------------------------
# propionate100_R3 yield=0.05493142857142856
# propionate100_R3 growth_rate=0.7370546321241211
# ---------------------------------------
# propionate50_R1 yield=0.04517904761904762
# propionate50_R1 growth_rate=0.2454426438747033
# ---------------------------------------
# propionate50_R2 yield=0.046441666666666666
# propionate50_R2 growth_rate=0.443801757105466
# ---------------------------------------
# propionate50_R3 yield=0.047766666666666666
# propionate50_R3 growth_rate=0.28796529812599225
# ---------------------------------------
# Thymidine2_R1 yield=0.142332
# Thymidine2_R1 growth_rate=0.8977167150456101
# ---------------------------------------
# Thymidine2_R2 yield=0.12706666666666666
# Thymidine2_R2 growth_rate=1.2618686112971516
# ---------------------------------------
# Thymidine2_R3 yield=0.14341666666666664
# Thymidine2_R3 growth_rate=1.4063900935978695
# ---------------------------------------
# Thymidine20_R1 yield=0.3496916666666667
# Thymidine20_R1 growth_rate=0.37840655803159506
# ---------------------------------------
# Thymidine20_R2 yield=0.4531644444444444
# Thymidine20_R2 growth_rate=0.5750985157896028
# ---------------------------------------
# Thymidine20_R3 yield=0.38922
# Thymidine20_R3 growth_rate=0.4088371471298206
# ---------------------------------------
# Thymidine40_R1 yield=0.314184
# Thymidine40_R1 growth_rate=0.43795052459884015
# ---------------------------------------
# Thymidine40_R2 yield=0.26458200000000004
# Thymidine40_R2 growth_rate=0.5091568324812676
# ---------------------------------------
# Thymidine40_R3 yield=0.2540106666666667
# Thymidine40_R3 growth_rate=0.4083691345777478
# ---------------------------------------
# asparagine10_R1 yield=0.043269696969696965
# asparagine10_R1 growth_rate=0.5205336612309136
# ---------------------------------------
# asparagine10_R2 yield=0.04559047619047619
# asparagine10_R2 growth_rate=0.4182456841282598
# ---------------------------------------
# asparagine10_R3 yield=0.04456190476190476
# asparagine10_R3 growth_rate=0.2553580146585244
# ---------------------------------------
# asparagine25_R1 yield=0.08163666666666666
# asparagine25_R1 growth_rate=0.4015747353214178
# ---------------------------------------
# asparagine25_R2 yield=0.110835
# asparagine25_R2 growth_rate=0.5451322702562024
# ---------------------------------------
# asparagine25_R3 yield=0.12924000000000002
# asparagine25_R3 growth_rate=0.34047947332452194
# ---------------------------------------
# asparagine5_R1 yield=0.031911794871794866
# asparagine5_R1 growth_rate=0.5424190317636696
# ---------------------------------------
# asparagine5_R2 yield=0.03197407407407407
# asparagine5_R2 growth_rate=0.5068996994756356
# ---------------------------------------
# asparagine5_R3 yield=0.03304190476190476
# asparagine5_R3 growth_rate=0.4126638828990827
# ---------------------------------------
# aspartica10_R1 yield=0.04199777777777778
# aspartica10_R1 growth_rate=0.31272207703868876
# ---------------------------------------
# aspartica10_R2 yield=0.04179555555555555
# aspartica10_R2 growth_rate=0.30504351788957274
# ---------------------------------------
# aspartica10_R3 yield=0.0489774358974359
# aspartica10_R3 growth_rate=2.706955518211242
# ---------------------------------------
# aspartica25_R1 yield=0.04360370370370371
# aspartica25_R1 growth_rate=0.35575087849173864
# ---------------------------------------
# aspartica25_R2 yield=0.06619333333333333
# aspartica25_R2 growth_rate=2.9513602456811885
# ---------------------------------------
# aspartica25_R3 yield=0.07292000000000001
# aspartica25_R3 growth_rate=1.6135622651840722
# ---------------------------------------
# aspartica5_R1 yield=0.034659999999999996
# aspartica5_R1 growth_rate=0.2985874728819292
# ---------------------------------------
# aspartica5_R2 yield=0.033689000000000004
# aspartica5_R2 growth_rate=0.3470464579427848
# ---------------------------------------
# aspartica5_R3 yield=0.032603939393939387
# aspartica5_R3 growth_rate=0.5120539208280923
# ---------------------------------------
# DLmalate10_R1 yield=0.38114785185185185
# DLmalate10_R1 growth_rate=0.41346078519589613
# ---------------------------------------
# DLmalate10_R2 yield=0.39356555555555556
# DLmalate10_R2 growth_rate=0.48742182313316856
# ---------------------------------------
# DLmalate10_R3 yield=0.40247948717948717
# DLmalate10_R3 growth_rate=0.6925569007119454
# ---------------------------------------
# DLmalate25_R1 yield=0.7466320634920636
# DLmalate25_R1 growth_rate=0.579114149238768
# ---------------------------------------
# DLmalate25_R2 yield=0.7547573333333334
# DLmalate25_R2 growth_rate=0.5259231904019357
# ---------------------------------------
# DLmalate25_R3 yield=0.7622296969696969
# DLmalate25_R3 growth_rate=0.3656347681106317
# ---------------------------------------
# DLmalate50_R1 yield=0.7849654545454544
# DLmalate50_R1 growth_rate=0.8924163566789233
# ---------------------------------------
# DLmalate50_R2 yield=0.38601710144927537
# DLmalate50_R2 growth_rate=0.6103690953659385
# ---------------------------------------
# DLmalate50_R3 yield=0.34334179487179495
# DLmalate50_R3 growth_rate=0.4907128852037402
# ---------------------------------------
# glc0.4_R1 yield=0.7793384126984128
# glc0.4_R1 growth_rate=0.7926809236029058
# ---------------------------------------
# glc0.4_R2 yield=0.6868948148148148
# glc0.4_R2 growth_rate=3.882829932834784
# ---------------------------------------
# glc0.4_R3 yield=0.683382962962963
# glc0.4_R3 growth_rate=1.2453052519200982
# ---------------------------------------
# glycylaspartica10_R1 yield=0.07259666666666666
# glycylaspartica10_R1 growth_rate=0.8193640276120394
# ---------------------------------------
# glycylaspartica10_R2 yield=0.082396
# glycylaspartica10_R2 growth_rate=0.8364300887483072
# ---------------------------------------
# glycylaspartica10_R3 yield=0.08056266666666666
# glycylaspartica10_R3 growth_rate=0.4632714657714035
# ---------------------------------------
# glycylaspartica25_R1 yield=0.13566
# glycylaspartica25_R1 growth_rate=0.37030206825586387
# ---------------------------------------
# glycylaspartica25_R2 yield=0.140104
# glycylaspartica25_R2 growth_rate=0.3314644339800594
# ---------------------------------------
# glycylaspartica25_R3 yield=0.16336666666666666
# glycylaspartica25_R3 growth_rate=0.2573860098017083
# ---------------------------------------
# glycylaspartica5_R1 yield=0.049569166666666664
# glycylaspartica5_R1 growth_rate=0.9981856574395146
# ---------------------------------------
# glycylaspartica5_R2 yield=0.049224761904761896
# glycylaspartica5_R2 growth_rate=0.5111518909836448
# ---------------------------------------
# glycylaspartica5_R3 yield=0.04880857142857142
# glycylaspartica5_R3 growth_rate=0.3700607083368619
# ---------------------------------------
# ketobutyrate1_R1 yield=0.032765333333333334
# ketobutyrate1_R1 growth_rate=0.532996542903094
# ---------------------------------------
# ketobutyrate1_R2 yield=0.036756
# ketobutyrate1_R2 growth_rate=0.4001760502845048
# ---------------------------------------
# ketobutyrate1_R3 yield=0.03455333333333333
# ketobutyrate1_R3 growth_rate=0.36398821849927815
# ---------------------------------------
# ketobutyrate2_R1 yield=0.0282
# ketobutyrate2_R1 growth_rate=0.2640127920624154
# ---------------------------------------
# ketobutyrate2_R2 yield=0.03177777777777777
# ketobutyrate2_R2 growth_rate=0.24037696841361647
# ---------------------------------------
# ketobutyrate2_R3 yield=0.042471999999999996
# ketobutyrate2_R3 growth_rate=0.29734438741761215
# ---------------------------------------
# ketobutyrate5_R1 yield=0.033497777777777786
# ketobutyrate5_R1 growth_rate=0.19224193110751472
# ---------------------------------------
# ketobutyrate5_R2 yield=0.06293333333333334
# ketobutyrate5_R2 growth_rate=0.6097156539578286
# ---------------------------------------
# ketobutyrate5_R3 yield=0.14163777777777778
# ketobutyrate5_R3 growth_rate=1.0232413052517235
# ---------------------------------------
# Lmalate10_R1 yield=0.32659166666666667
# Lmalate10_R1 growth_rate=0.9156709232519421
# ---------------------------------------
# Lmalate10_R2 yield=0.3430916666666667
# Lmalate10_R2 growth_rate=0.8943517885178018
# ---------------------------------------
# Lmalate10_R3 yield=0.32354476190476195
# Lmalate10_R3 growth_rate=0.42651344228704147
# ---------------------------------------
# Lmalate25_R1 yield=0.7770999999999999
# Lmalate25_R1 growth_rate=0.9035092379116959
# ---------------------------------------
# Lmalate25_R2 yield=0.7694058333333333
# Lmalate25_R2 growth_rate=0.4375617373233834
# ---------------------------------------
# Lmalate25_R3 yield=0.7561088888888889
# Lmalate25_R3 growth_rate=0.6659236035995617
# ---------------------------------------
# Lmalate50_R1 yield=0.7473662962962963
# Lmalate50_R1 growth_rate=0.513830249934876
# ---------------------------------------
# Lmalate50_R2 yield=0.7534673684210527
# Lmalate50_R2 growth_rate=0.446794124205054
# ---------------------------------------
# Lmalate50_R3 yield=0.7776484057971011
# Lmalate50_R3 growth_rate=0.6943531276703667
# ---------------------------------------

# %% [markdown]
# # For the name with _R1 _R2 _R3

# %%
import os
import pandas as pd
from itertools import groupby 

def getfiles(folderPath):
    pths = []
    for root, dirs, files in os.walk(folderPath):
        for fn in files:            
            if fn.endswith('.csv') and 'stats' in fn:
                pth = os.path.join(root, fn)
                pths.append(pth)
    return pths

csv_folder_path = './csv'
pths = getfiles(csv_folder_path)

extrac_gr = "Growth Rate"
extrac_yi = "yield"

yield_list = []
growth_rate_list = []
name_list = []
for path in pths:
    print path
    data = pd.read_csv(path)
    data2 = data.set_index(data.columns[0])
    index = data.iloc[:,0]
    # initializing list  
    test_list = list(index)
    # sort list  
    # essential for grouping 
    test_list.sort() 
    # printing the original list  
    # using lambda + itertools.groupby() + split() 
    # group similar substrings 
    group_ind = [list(i) for j, i in groupby(test_list, 
                      lambda a: a.split('_')[0])]    
    
    for g in group_ind:
        #print g
        yield_dict = dict()
        growth_dict = dict()
        i = 1
        for strain in g:
            init = 'R'+str(i)
            yield_dict[init] = data2.loc[strain,extrac_yi]
            growth_dict[init] = data2.loc[strain, extrac_gr]
            i = i +1
        yield_list.append(yield_dict)
        growth_rate_list.append(growth_dict)
        name_list.append(g[0].split('_')[0])
# Out:
# ./csv/MG1655 10082019 N-stats.csv
# ./csv/MG1655 25062019-stats.csv
# ./csv/MG1655 22062019-stats.csv
# ./csv/MG1655 14082019 N-stats.csv
# ./csv/MG1655 20082019 N-stats.csv
# ./csv/MG1655 23062019-stats.csv
# ./csv/MG1655 17082019 N-stats.csv
# ./csv/MG1655 13082019 N-stats.csv
# ./csv/MG1655 24062019-stats.csv
# ./csv/MG1655 19062019-stats.csv
# ./csv/MG1655 07072019-stats.csv
# ./csv/MG1655 29062019-stats.csv
# ./csv/MG1655 03082019-stats.csv
# ./csv/MG1655 14062019-stats.csv
# ./csv/MG1655 26062019-stats.csv
# ./csv/MG1655 08072019-stats.csv
# ./csv/MG1655 28062019-stats.csv
# ./csv/MG1655 02082019-stats.csv
# ./csv/MG1655 27062019-stats.csv
# ./csv/MG1655 05082019-stats.csv

# %%
fn = os.path.split(csv_folder_path)[1]

df = pd.DataFrame(yield_list) 
df = df.set_index([pd.Index(name_list)])
df
df.to_csv('./results/yield_all_strains_'+fn+'.csv')

df = pd.DataFrame(growth_rate_list) 
df = df.set_index([pd.Index(name_list)])
df
df.to_csv('./results/growth_rate_all_strains_'+fn+'.csv')

# %% [markdown]
# # Load csv for the name without _R1 _R2 _R3

# %%
import os
import pandas as pd

def getfiles(folderPath):
    pths = []
    for root, dirs, files in os.walk(folderPath):
        for fn in files:            
            if fn.endswith('.csv') and 'stats' in fn:
                pth = os.path.join(root, fn)
                pths.append(pth)
    return pths

csv_folder_path = './carbon_source'
pths = getfiles(csv_folder_path)

extrac_gr = "Growth Rate"
extrac_yi = "yield"

yield_list = []
growth_rate_list = []
name_list = []
for path in pths:
    print path
    data = pd.read_csv(path)
    data2 = data.set_index(data.columns[0])
    pre_strain ='no'
    for strain in data2.index:
        if pre_strain not in strain:
            try:
                if pre_strain != 'no':
                    print "s3",pre_strain
                    yield_list.append(yield_dict)
                    growth_rate_list.append(growth_dict)
                    name_list.append(pre_strain)
            except:
                print pre_strain,strain

        if pre_strain != strain:
            if pre_strain not in strain:
                pre_strain = strain
                #name_list.append(pre_strain)
                #print "s1",pre_strain, strain
                i = 1
                yield_dict = dict()
                growth_dict = dict()

        init = 'R'+str(i)
        if pre_strain in strain:
            #print "s2",pre_strain, strain
            #print init,data2.loc[strain,extrac]
            yield_dict[init] = data2.loc[strain,extrac_yi]
            growth_dict[init] = data2.loc[strain, extrac_gr]
            i = i +1


print "last s3",pre_strain
yield_list.append(yield_dict)
growth_rate_list.append(growth_dict)
name_list.append(pre_strain)
# Out:
# ./carbon_source/Glc v Carbon sources 6 version 2-stats.csv
# s3 DLmalate10_R1
# s3 DLmalate10_R2
# s3 DLmalate10_R3
# s3 DLmalate25_R1
# s3 DLmalate25_R2
# s3 DLmalate25_R3
# s3 DLmalate50_R1
# s3 DLmalate50_R2
# s3 DLmalate50_R3
# s3 glc0.4_R1
# s3 glc0.4_R2
# s3 glc0.4_R3
# s3 glucuronica10_R1
# s3 glucuronica10_R2
# s3 glucuronica10_R3
# s3 glucuronica25_R1
# s3 glucuronica25_R2
# s3 glucuronica25_R3
# s3 glucuronica50_R1
# s3 glucuronica50_R2
# s3 glucuronica50_R3
# s3 ketobutyrica1_R1
# s3 ketobutyrica1_R2
# s3 ketobutyrica1_R3
# s3 ketobutyrica2_R1
# s3 ketobutyrica2_R2
# s3 ketobutyrica2_R3
# s3 ketobutyrica5_R1
# s3 ketobutyrica5_R2
# s3 ketobutyrica5_R3
# s3 Llactate10_R1
# s3 Llactate10_R2
# s3 Llactate10_R3
# s3 Llactate25_R1
# s3 Llactate25_R2
# s3 Llactate25_R3
# s3 Llactate5_R1
# s3 Llactate5_R2
# s3 Llactate5_R3
# s3 methylpyr10_R1
# s3 methylpyr10_R2
# s3 methylpyr10_R3
# s3 methylpyr25_R1
# s3 methylpyr25_R2
# s3 methylpyr25_R3
# s3 methylpyr5_R1
# s3 methylpyr5_R2
# s3 methylpyr5_R3
# s3 Saccharicac0.9_R1
# s3 Saccharicac0.9_R2
# s3 Saccharicac0.9_R3
# s3 Saccharicac18_R1
# s3 Saccharicac18_R2
# s3 Saccharicac18_R3
# s3 Saccharicac9_R1
# s3 Saccharicac9_R2
# ./carbon_source/Glc v Carbon sources 7 version 2-stats.csv
# s3 asparagine10_R1
# s3 asparagine10_R2
# s3 asparagine10_R3
# s3 asparagine25_R1
# s3 asparagine25_R2
# s3 asparagine25_R3
# s3 asparagine5_R1
# s3 asparagine5_R2
# s3 asparagine5_R3
# s3 aspartica10_R1
# s3 aspartica10_R2
# s3 aspartica10_R3
# s3 aspartica25_R1
# s3 aspartica25_R2
# s3 aspartica25_R3
# s3 aspartica5_R1
# s3 aspartica5_R2
# s3 aspartica5_R3
# s3 DLmalate10_R1
# s3 DLmalate10_R2
# s3 DLmalate10_R3
# s3 DLmalate25_R1
# s3 DLmalate25_R2
# s3 DLmalate25_R3
# s3 DLmalate50_R1
# s3 DLmalate50_R2
# s3 DLmalate50_R3
# s3 glc0.4_R1
# s3 glc0.4_R2
# s3 glc0.4_R3
# s3 glycylaspartica10_R1
# s3 glycylaspartica10_R2
# s3 glycylaspartica10_R3
# s3 glycylaspartica25_R1
# s3 glycylaspartica25_R2
# s3 glycylaspartica25_R3
# s3 glycylaspartica5_R1
# s3 glycylaspartica5_R2
# s3 glycylaspartica5_R3
# s3 ketobutyrate1_R1
# s3 ketobutyrate1_R2
# s3 ketobutyrate1_R3
# s3 ketobutyrate2_R1
# s3 ketobutyrate2_R2
# s3 ketobutyrate2_R3
# s3 ketobutyrate5_R1
# s3 ketobutyrate5_R2
# s3 ketobutyrate5_R3
# s3 Lmalate10_R1
# s3 Lmalate10_R2
# s3 Lmalate10_R3
# s3 Lmalate25_R1
# s3 Lmalate25_R2
# s3 Lmalate25_R3
# s3 Lmalate50_R1
# s3 Lmalate50_R2
# ./carbon_source/Glc v Carbon sources 4 version 2-stats.csv
# s3 DSerine10_R1
# s3 DSerine10_R2
# s3 DSerine10_R3
# s3 DSerine25_R1
# s3 DSerine25_R2
# s3 DSerine25_R3
# s3 DSerine5_R1
# s3 DSerine5_R2
# s3 DSerine5_R3
# s3 glc0.4_R1
# s3 glc0.4_R2
# s3 glc0.4_R3
# s3 GlycylAspartic10_R1
# s3 GlycylAspartic10_R2
# s3 GlycylAspartic10_R3
# s3 GlycylAspartic25_R1
# s3 GlycylAspartic25_R2
# s3 GlycylAspartic25_R3
# s3 GlycylAspartic5_R1
# s3 GlycylAspartic5_R2
# s3 GlycylAspartic5_R3
# s3 Ketoglutarate10_R1
# s3 Ketoglutarate10_R2
# s3 Ketoglutarate10_R3
# s3 Ketoglutarate15_R1
# s3 Ketoglutarate15_R2
# s3 Ketoglutarate15_R3
# s3 Ketoglutarate5_R1
# s3 Ketoglutarate5_R2
# s3 Ketoglutarate5_R3
# s3 Lasparagine10_R1
# s3 Lasparagine10_R2
# s3 Lasparagine10_R3
# s3 Lasparagine25_R1
# s3 Lasparagine25_R2
# s3 Lasparagine25_R3
# s3 Lasparagine5_R1
# s3 Lasparagine5_R2
# s3 Lasparagine5_R3
# s3 Laspartic10_R1
# s3 Laspartic10_R2
# s3 Laspartic10_R3
# s3 Laspartic25_R1
# s3 Laspartic25_R2
# s3 Laspartic25_R3
# s3 Laspartic5_R1
# s3 Laspartic5_R2
# s3 Laspartic5_R3
# s3 Tartaric10_R1
# s3 Tartaric10_R2
# s3 Tartaric10_R3
# s3 Tartaric25_R1
# s3 Tartaric25_R2
# s3 Tartaric25_R3
# s3 Tartaric5_R1
# s3 Tartaric5_R2
# ./carbon_source/Glc v Carbon sources 5 version 2-stats.csv
# s3 galactose10_R1
# s3 galactose10_R2
# s3 galactose10_R3
# s3 galactose100_R1
# s3 galactose100_R2
# s3 galactose100_R3
# s3 galactose200_R1
# s3 galactose200_R2
# s3 galactose200_R3
# s3 glc0.4_R1
# s3 glc0.4_R2
# s3 glc0.4_R3
# s3 LAlanine10_R1
# s3 LAlanine10_R2
# s3 LAlanine10_R3
# s3 LAlanine100_R1
# s3 LAlanine100_R2
# s3 LAlanine100_R3
# s3 LAlanine200_R1
# s3 LAlanine200_R2
# s3 LAlanine200_R3
# s3 pyruvate10_R1
# s3 pyruvate10_R2
# s3 pyruvate10_R3
# s3 pyruvate100_R1
# s3 pyruvate100_R2
# s3 pyruvate100_R3
# s3 pyruvate200_R1
# s3 pyruvate200_R2
# s3 pyruvate200_R3
# s3 Ribose10_R1
# s3 Ribose10_R2
# s3 Ribose10_R3
# s3 Ribose100_R1
# s3 Ribose100_R2
# s3 Ribose100_R3
# s3 Ribose200_R1
# s3 Ribose200_R2
# s3 Ribose200_R3
# s3 Sorbitol10_R1
# s3 Sorbitol10_R2
# s3 Sorbitol10_R3
# s3 Sorbitol100_R1
# s3 Sorbitol100_R2
# s3 Sorbitol100_R3
# s3 Sorbitol200_R1
# s3 Sorbitol200_R2
# s3 Sorbitol200_R3
# s3 uridine10_R1
# s3 uridine10_R2
# s3 uridine10_R3
# s3 uridine100_R1
# s3 uridine100_R2
# s3 uridine100_R3
# s3 uridine200_R1
# s3 uridine200_R2
# ./carbon_source/Glc v Carbon sources 3 version 2-stats.csv
# s3 Dglucosamine10_R1
# s3 Dglucosamine10_R2
# s3 Dglucosamine10_R3
# s3 Dglucosamine100_R1
# s3 Dglucosamine100_R2
# s3 Dglucosamine100_R3
# s3 Dglucosamine200_R1
# s3 Dglucosamine200_R2
# s3 Dglucosamine200_R3
# s3 dulcitol10_R1
# s3 dulcitol10_R2
# s3 dulcitol10_R3
# s3 dulcitol5_R1
# s3 dulcitol5_R2
# s3 dulcitol5_R3
# s3 dulcitol50_R1
# s3 dulcitol50_R2
# s3 dulcitol50_R3
# s3 glc0.4_R1
# s3 glc0.4_R2
# s3 glc0.4_R3
# s3 Inosine0.8_R1
# s3 Inosine0.8_R2
# s3 Inosine0.8_R3
# s3 Inosine16_R1
# s3 Inosine16_R2
# s3 Inosine16_R3
# s3 Inosine8_R1
# s3 Inosine8_R2
# s3 Inosine8_R3
# s3 propionate10_R1
# s3 propionate10_R2
# s3 propionate10_R3
# s3 propionate100_R1
# s3 propionate100_R2
# s3 propionate100_R3
# s3 propionate50_R1
# s3 propionate50_R2
# s3 propionate50_R3
# s3 Thymidine2_R1
# s3 Thymidine2_R2
# s3 Thymidine2_R3
# s3 Thymidine20_R1
# s3 Thymidine20_R2
# s3 Thymidine20_R3
# s3 Thymidine40_R1
# s3 Thymidine40_R2
# ./carbon_source/Glc v Carbon sources 2 version 2-stats.csv
# s3 Acetate10_R1
# s3 Acetate10_R2
# s3 Acetate10_R3
# s3 Acetate100_R1
# s3 Acetate100_R2
# s3 Acetate100_R3
# s3 Acetate200_R1
# s3 Acetate200_R2
# s3 Acetate200_R3
# s3 DAl10_R1
# s3 DAl10_R2
# s3 DAl10_R3
# s3 DAl100_R1
# s3 DAl100_R2
# s3 DAl100_R3
# s3 DAl200_R1
# s3 DAl200_R2
# s3 DAl200_R3
# s3 glc0.4_R1
# s3 glc0.4_R2
# s3 glc0.4_R3
# s3 Maltose10_R1
# s3 Maltose10_R2
# s3 Maltose10_R3
# s3 Maltose100_R2
# s3 Maltose100_R3
# s3 Maltose100_R4
# s3 Maltose200_R1
# s3 Maltose200_R2
# s3 Maltose200_R3
# s3 Mannitol10_R1
# s3 Mannitol10_R2
# s3 Mannitol10_R3
# s3 Mannitol100_R1
# s3 Mannitol100_R2
# s3 Mannitol100_R3
# s3 Mannitol200_R1
# s3 Mannitol200_R2
# s3 Mannitol200_R3
# s3 Succinate10_R1
# s3 Succinate10_R2
# s3 Succinate10_R3
# s3 Succinate100_R1
# s3 Succinate100_R2
# s3 Succinate100_R3
# s3 Succinate200_R1
# s3 Succinate200_R2
# s3 Succinate200_R3
# s3 xyl10_R1
# s3 xyl10_R2
# s3 xyl10_R3
# s3 xyl100_R1
# s3 xyl100_R2
# s3 xyl100_R3
# s3 xyl200_R1
# s3 xyl200_R2
# ./carbon_source/Glc v Carbon sources 1 version 2-stats.csv
# s3 Fru10_R1
# s3 Fru10_R2
# s3 Fru10_R3
# s3 Fru100_R1
# s3 Fru100_R2
# s3 Fru100_R3
# s3 Fru200_R1
# s3 Fru200_R2
# s3 Fru200_R3
# s3 Fum10_R1
# s3 Fum10_R2
# s3 Fum10_R3
# s3 Fum100_R1
# s3 Fum100_R2
# s3 Fum100_R3
# s3 Fum200_R1
# s3 Fum200_R2
# s3 Fum200_R3
# s3 Glc0.4_R1
# s3 Glc0.4_R2
# s3 Glc0.4_R3
# s3 Glu10_R1
# s3 Glu10_R2
# s3 Glu10_R3
# s3 Glu100_R1
# s3 Glu100_R2
# s3 Glu100_R3
# s3 Glu200_R1
# s3 Glu200_R2
# s3 Glu200_R3
# s3 Gly10_R1
# s3 Gly10_R2
# s3 Gly10_R3
# s3 Gly100_R1
# s3 Gly100_R2
# s3 Gly100_R3
# s3 Gly200_R1
# s3 Gly200_R2
# s3 Gly200_R3
# s3 pro10_R1
# s3 pro10_R2
# s3 pro10_R3
# s3 pro100_R1
# s3 pro100_R2
# s3 pro100_R3
# s3 pro200_R1
# s3 pro200_R2
# s3 pro200_R3
# s3 tre0_R1
# s3 tre0_R2
# s3 tre0_R3
# s3 tre00_R1
# s3 tre00_R2
# s3 tre00_R3
# s3 tre00_R1.1
# s3 tre00_R2.1
# ./carbon_source/Different glucose concentrations version 2-stats.csv
# s3 glc10uL_R1
# s3 glc10uL_R2
# s3 glc10uL_R3
# s3 glc10uL_R4
# s3 glc10uL_R5
# s3 glc100uL_R1
# s3 glc100uL_R2
# s3 glc100uL_R3
# s3 glc100uL_R4
# s3 glc100uL_R5
# s3 glc20uL_R1
# s3 glc20uL_R2
# s3 glc20uL_R3
# s3 glc20uL_R4
# s3 glc20uL_R5
# s3 glc30uL_R1
# s3 glc30uL_R2
# s3 glc30uL_R3
# s3 glc30uL_R4
# s3 glc30uL_R5
# s3 glc40uL_R1
# s3 glc40uL_R2
# s3 glc40uL_R3
# s3 glc40uL_R4
# s3 glc40uL_R5
# s3 glc50uL_R1
# s3 glc50uL_R2
# s3 glc50uL_R3
# s3 glc50uL_R4
# s3 glc50uL_R5
# s3 glc60uL_R1
# s3 glc60uL_R2
# s3 glc60uL_R3
# s3 glc60uL_R4
# s3 glc60uL_R5
# s3 glc70uL_R1
# s3 glc70uL_R2
# s3 glc70uL_R3
# s3 glc70uL_R4
# s3 glc70uL_R5
# s3 glc80uL_R1
# s3 glc80uL_R2
# s3 glc80uL_R3
# s3 glc80uL_R4
# s3 glc80uL_R5
# s3 glc90uL_R1
# s3 glc90uL_R2
# s3 glc90uL_R3
# s3 glc90uL_R4
# last s3 glc90uL_R5

# %%
data2.index
# Out:
# Index([u'glc10uL_R1', u'glc10uL_R2', u'glc10uL_R3', u'glc10uL_R4',
#        u'glc10uL_R5', u'glc100uL_R1', u'glc100uL_R2', u'glc100uL_R3',
#        u'glc100uL_R4', u'glc100uL_R5', u'glc20uL_R1', u'glc20uL_R2',
#        u'glc20uL_R3', u'glc20uL_R4', u'glc20uL_R5', u'glc30uL_R1',
#        u'glc30uL_R2', u'glc30uL_R3', u'glc30uL_R4', u'glc30uL_R5',
#        u'glc40uL_R1', u'glc40uL_R2', u'glc40uL_R3', u'glc40uL_R4',
#        u'glc40uL_R5', u'glc50uL_R1', u'glc50uL_R2', u'glc50uL_R3',
#        u'glc50uL_R4', u'glc50uL_R5', u'glc60uL_R1', u'glc60uL_R2',
#        u'glc60uL_R3', u'glc60uL_R4', u'glc60uL_R5', u'glc70uL_R1',
#        u'glc70uL_R2', u'glc70uL_R3', u'glc70uL_R4', u'glc70uL_R5',
#        u'glc80uL_R1', u'glc80uL_R2', u'glc80uL_R3', u'glc80uL_R4',
#        u'glc80uL_R5', u'glc90uL_R1', u'glc90uL_R2', u'glc90uL_R3',
#        u'glc90uL_R4', u'glc90uL_R5'],
#       dtype='object', name=u'Unnamed: 0')

# %%
fn = os.path.split(csv_folder_path)[1]

df = pd.DataFrame(yield_list) 
df = df.set_index([pd.Index(name_list)])
df
df.to_csv('./results/yield_all_strains_'+fn+'.csv')

df = pd.DataFrame(growth_rate_list) 
df = df.set_index([pd.Index(name_list)])
df
df.to_csv('./results/growth_rate_all_strains_'+fn+'.csv')
