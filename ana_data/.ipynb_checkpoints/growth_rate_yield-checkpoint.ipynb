# %%
def smooth(a,WSZ=5):
    # a: NumPy 1-D array containing the data to be smoothed
    # WSZ: smoothing window size needs, which must be odd number,
    # as in the original MATLAB implementation
    out0 = np.convolve(a,np.ones(WSZ,dtype=int),'valid')/WSZ    
    r = np.arange(1,WSZ-1,2)

    start = np.cumsum(a[:WSZ-1])[::2]/r
    #print start,out0
    stop = (np.cumsum(a[:-WSZ:-1])[::2]/r)[::-1]
    return np.concatenate((  start , out0, stop  ))

def digitalOnly(s):
    import string
    al=string.maketrans('','')
    nodigs=al.translate(al, string.digits)
    return s.translate(al, nodigs)

def getLinearRegressionCoef(X,y):
    import numpy as np
    from sklearn.linear_model import LinearRegression
    reg = LinearRegression().fit(X, y)
    reg.score(X, y)    
    return reg.coef_


def computeDerivetive_od(t, sOD, wsz = 5):
    from numpy import isnan
    coef_OD = np.zeros(len(sOD))
    t_mean = np.zeros(len(sOD))
    j = 0
    nan_found = False
    for i in range(len(sOD)):
        t_wsz = t[i-wsz/2:i+wsz/2+1]        
        sOD_wsz = np.expand_dims(np.log(sOD[i-wsz/2:i+wsz/2+1]),axis=1)    
        if len(sOD_wsz)!= wsz:
            coef_OD[i] = 0
        else:                
            if len(t_wsz)==len(sOD_wsz):                
                where_are_NaNs = isnan(sOD_wsz)
                if any(where_are_NaNs):
                    sOD_wsz[where_are_NaNs] = np.mean(sOD_wsz[~where_are_NaNs])
                    print "nan Found in array, replaced by mean value of the rest"

                coef_OD[i]=getLinearRegressionCoef(t_wsz,sOD_wsz)
                t_mean[i] = np.mean(t_wsz)
    
    dt = t_mean[wsz/2:len(t_mean)-wsz/2]
    dt_pad = np.pad(dt,[wsz/2,wsz/2],'reflect',reflect_type='odd')
    
    return coef_OD, dt_pad


def draw_tangent(x1,y1,ind,e=0.1,plot=False):
    from scipy import interpolate
    import numpy as np
    import matplotlib.pyplot as plt
    x = np.squeeze(x1)
    y = np.squeeze(y1)
    # interpolate the data with a spline
    spl = interpolate.splrep(x,y)
    a = x[ind]
    fa = interpolate.splev(a,spl,der=0)     # f(a)
    fprime = interpolate.splev(a,spl,der=1) # f'(a)
    left = 0
    for i in range(ind,0,-1):        
        a_i = x[i]
        y_i = y[i]        
        tan_i = fa+fprime*(a_i-a) # tangent                
        if abs(tan_i-y_i) > abs(y[ind]*e):
            left = i
            break    
    right = len(x) - 1
    for i in range(ind+1,len(x)):        
        a_i = x[i]
        y_i = y[i]
        tan_i = fa+fprime*(a_i-a) # tangent        
        if abs(tan_i-y_i) > abs(y[ind]*e):
            right = i
            break
    small_t = np.linspace(x[left],x[right],10)
    tan = fa+fprime*(small_t-a) # tangent    
    if plot:
        plt.plot(a,fa,'om',small_t,tan,'--r')
        plt.plot(x,y)
    return left, right,small_t,tan


def getTimepoints_old(coef_OD,sOD_log, dt_pad,start_ind, thres=0.03, thres_range=0.8):
    coef_OD_fromStart_ind = coef_OD[start_ind:]
    ind = np.argmax(coef_OD_fromStart_ind) + start_ind        
    max_v = coef_OD[ind]
    
    time_max_coefod = dt_pad[ind]        
    right_side_exp = len(coef_OD)-1
    left_side_exp = 0
    for k in range(ind+1,len(coef_OD)):
        v_od = coef_OD[k]
        if (max_v-v_od)/max_v > 1-thres_range:
            right_side_exp = k
            break

    for k in reversed(range(ind)):
        v_od = coef_OD[k]
        if (max_v-v_od)/max_v > 1-thres_range:
            left_side_exp = k
            break

    time_left = dt_pad[left_side_exp]
    time_right = dt_pad[right_side_exp]  
    
    return time_max_coefod,time_left,time_right,left_side_exp,right_side_exp

def getTimepoints(coef_OD,sOD_log,dt_pad,start_ind):
    coef_OD_fromStart_ind = coef_OD[start_ind:]
    ind = np.argmax(coef_OD_fromStart_ind) + start_ind        
    max_v = coef_OD[ind]
    time_max_coefod = dt_pad[ind]        
    left_side_exp, right_side_exp,small_t,tan = draw_tangent(dt_pad,sOD_log,ind)
    time_left = dt_pad[left_side_exp]
    time_right = dt_pad[right_side_exp]  
    return time_max_coefod,time_left,time_right,left_side_exp,right_side_exp,small_t,tan


def getPostiveStart(sOD):
    start_positive = 0
    for o in range(start_positive, len(sOD)):
        if sOD[o] <= 0:
            start_positive = o + 1
    if start_positive >= len(sOD):
        start_positive = -1
    return start_positive

def mkdir_p(path):
    import errno    
    import os
    try:
        os.makedirs(path)
    except OSError as exc:  # Python >2.5
        if exc.errno == errno.EEXIST and os.path.isdir(path):
            pass
        else:
            raise
            
            
def getStationaryTime(sOD):
    sOD = np.asarray(sOD)
    sta_index = len(sOD)-1
    last_value = sOD[sta_index]
    for i in range(len(sOD)-2,0,-1):
        if (abs(last_value-sOD[i])/last_value)>0.05:
            sta_index = i
            #print "stationary phase found"
            break
    return sta_index

def mkdir_p(path):
    import errno    
    import os
    try:
        os.makedirs(path)
    except OSError as exc:  # Python >2.5
        if exc.errno == errno.EEXIST and os.path.isdir(path):
            pass
        else:
            raise

# %%
import os
import pandas as pd

def getfiles(folderPath):
    pths = []
    for root, dirs, files in os.walk(folderPath):
        for fn in files:            
            if fn.endswith('.csv') and 'stats' not in fn:
                pth = os.path.join(root, fn)
                pths.append(pth)
    return pths

pths = getfiles('csv_new')

for path in pths:
    folder = path.split('.')[0]
    mkdir_p(folder)
    data = pd.read_csv(path)    
    
    import numpy as np
    import matplotlib.pyplot as plt
    import os
    time = data.iloc[:,0]
    m_od = data.iloc[0:,1:]
    strains = list(m_od.columns)
    t = time.values

    t_k = (t[1:len(t)] - t[0:len(t)-1])/3600
    t_k = np.cumsum(t_k)
    t_k = np.insert(t_k,0,0)
    t_k = t_k.reshape(-1,1)
    t = t_k

    blank_od = 0.04
    pre_max_v = 0.7

    growth_rate_dict = dict()
    lag_phase_dict = dict()
    yield_dict = dict()
    for name in strains:
        od = m_od[name].values
        od_array = od - np.min(blank_od)
        od_array = np.squeeze(np.asarray(od_array))
        sOD = smooth(od_array)    
        sOD_log = np.log(sOD)
        
        try:
            coef_OD, dt_pad = computeDerivetive_od(t, sOD)
        except:
            continue
        ind_max_dODdt = np.argmax(coef_OD)
        OD_exp = sOD[ind_max_dODdt]
        time_max_dODdt = dt_pad[ind_max_dODdt]
        start_positive = getPostiveStart(sOD)
        if start_positive > 0:
            print name,'found negative od ', start_positive    
        lag_phase_pre = time_max_dODdt - np.log(OD_exp/sOD[start_positive])/pre_max_v
        m = t < lag_phase_pre
        start_ind = np.sum(m)

        time_max_od,time_left, time_right,left_side_exp,right_side_exp,small_t,tan = getTimepoints(coef_OD,sOD_log,dt_pad,start_ind)

        time_max_dODdt = dt_pad[ind_max_dODdt]

        od_max_coef = coef_OD[ind_max_dODdt]

        ind = np.argmax(coef_OD)        
        max_v = coef_OD[ind]    
        growth_rate = max_v

        # Update lag_phase using growth rate in an estimated window
        lag_phase_pre = time_max_dODdt - np.log(OD_exp/sOD[start_positive])/max_v
        lag_phase = lag_phase_pre

        sta_index = getStationaryTime(sOD)
        t_sta = dt_pad[sta_index]

        yield_mean = np.mean(sOD[sta_index:])
        print name+' yield'+"="+str(yield_mean)


        x = t_k
        y = sOD_log
        plt.plot(x,y,label='log(OD)')
        plt.plot(x,y,small_t,tan,'--r',label='log(OD)')
        plt.title(name)
        plt.xlabel("time")
        w = coef_OD
        plt.plot(x, w,label='dOD/dt/OD') # can c                
        plt.axvline(x=time_max_od,linestyle=':',color='green')
        plt.legend()
        plt.savefig(os.path.join(folder,name +'-dODdtOD.png'))
        plt.close()   

        plt.plot(x,sOD,label='OD')    
        plt.axvline(x=time_left,linestyle=':',color='red')
        plt.axvline(x=time_max_od,linestyle=':',color='green')
        plt.axvline(x=t_sta,linestyle=':',color='yellow')
        plt.axvline(x=time_right,linestyle=':',color='red')
        plt.axvline(x=lag_phase,linestyle=':',color='purple')    
        plt.xlabel('time')
        plt.title(name)        
        plt.legend()
        plt.savefig(os.path.join(folder,name +'-OD.png'))
        plt.close()

        growth_rate_dict[name] = growth_rate
        lag_phase_dict[name] = lag_phase
        yield_dict[name] = yield_mean

    df = pd.DataFrame.from_dict([growth_rate_dict,lag_phase_dict, yield_dict])
    df = df.transpose()
    df2 = df.reindex(strains)
    df2.columns = ['Growth Rate', 'Lag Phase', 'yield']
    df2.to_csv(folder +'-stats.csv')
# Out:
# asparagine 10 yield=0.043269696969696965
# asparagine 10.1 yield=0.04559047619047619
# asparagine 10.2 yield=0.04456190476190476
# asparagine 25 yield=0.08163666666666666
# asparagine 25.1 yield=0.110835
# asparagine 25.2 yield=0.12924000000000002
# asparagine 5 yield=0.031911794871794866
# asparagine 5.1 yield=0.03197407407407407
# asparagine 5.2 yield=0.03304190476190476
# aspartic a 10 yield=0.04199777777777778
# aspartic a 10.1 yield=0.04179555555555555
# aspartic a 10.2 yield=0.0489774358974359
# aspartic a 25 yield=0.04360370370370371
# aspartic a 25.1 yield=0.06619333333333333
# aspartic a 25.2 yield=0.07292000000000001
# aspartic a 5 yield=0.034659999999999996
# aspartic a 5.1 yield=0.033689000000000004
# aspartic a 5.2 yield=0.032603939393939387
# DL malate 10 yield=0.38114785185185185
# DL malate 10.1 yield=0.39356555555555556
# DL malate 10.2 yield=0.40247948717948717
# DL malate 25 yield=0.7466320634920636
# DL malate 25.1 yield=0.7547573333333334
# DL malate 25.2 yield=0.7622296969696969
# DL malate 50 yield=0.7849654545454544
# DL malate 50.1 yield=0.38601710144927537
# DL malate 50.2 yield=0.34334179487179495
# glc 0 yield=0.7793384126984128
# 4% yield=0.6868948148148148
# glc 0.1 yield=0.683382962962963
# 4%.1 yield=0.07259666666666666
# glc 0.2 yield=0.082396
# 4%.2 yield=0.08056266666666666
# glycyl aspartic a 10 yield=0.13566
# glycyl aspartic a 10.1 yield=0.140104
# glycyl aspartic a 10.2 yield=0.16336666666666666
# glycyl aspartic a 25 yield=0.049569166666666664
# glycyl aspartic a 25.1 yield=0.049224761904761896
# glycyl aspartic a 25.2 yield=0.04880857142857142
# glycyl aspartic a 5 yield=0.032765333333333334
# glycyl aspartic a 5.1 yield=0.036756
# glycyl aspartic a 5.2 yield=0.03455333333333333
# ketobutyrate 1 yield=0.0282
# ketobutyrate 1.1 yield=0.03177777777777777
# ketobutyrate 1.2 yield=0.042471999999999996
# ketobutyrate 2 yield=0.033497777777777786
# ketobutyrate 2.1 yield=0.06293333333333334
# ketobutyrate 2.2 yield=0.14163777777777778
# ketobutyrate 5 yield=0.32659166666666667
# ketobutyrate 5.1 yield=0.3430916666666667
# ketobutyrate 5.2 yield=0.32354476190476195
# L malate 10 yield=0.7770999999999999
# L malate 10.1 yield=0.7694058333333333
# L malate 10.2 yield=0.7561088888888889
# L malate 25 yield=0.7473662962962963
# L malate 25.1 yield=0.7534673684210527
# L malate 25.2 yield=0.7776484057971011
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# /home/xsong/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in log
# /home/xsong/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in log
# Acetate 10 yield=0.2888744444444445
# Acetate 10.1 yield=0.21331714285714282
# Acetate 10.2 yield=0.20805185185185182
# Acetate 100 yield=0.09806
# Acetate 100.1 yield=0.09279666666666665
# Acetate 100.2 yield=0.0884142857142857
# Acetate 200 yield=0.04789333333333333
# Acetate 200.1 yield=0.0483569696969697
# Acetate 200.2 yield=0.055877777777777776
# D Al 10 yield=0.29520777777777774
# D Al 10.1 yield=0.2587052380952381
# D Al 10.2 yield=0.31004000000000004
# D Al 100 yield=0.3067026666666667
# D Al 100.1 yield=0.31589222222222224
# D Al 100.2 yield=0.34530000000000005
# D Al 200 yield=0.18719904761904763
# D Al 200.1 yield=0.16935
# D Al 200.2 yield=0.1558422222222222
# glc 0 yield=0.8055541025641026
# 4 yield=0.6596616216216216
# glc 0.1 yield=0.6084315384615384
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# /home/xsong/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: divide by zero encountered in log
# nan Found in array, replaced by mean value of the rest
# M9 yield=0.6222995238095237
# M9.1 yield=0.6816946666666667
# M9.2 yield=0.6523155555555554
# Maltose 10 yield=0.472148
# Maltose 10.1 yield=0.4652325
# Maltose 10.2 yield=0.484714358974359
# Maltose 100 yield=0.3363252380952381
# Maltose 100.1 yield=0.3302298039215687
# Maltose 100.2 yield=0.32414966666666667
# Maltose 200 yield=0.5603941666666666
# Maltose 200.1 yield=0.5642564444444443
# Maltose 200.2 yield=0.618520606060606
# Mannitol 10 yield=0.623494
# Mannitol 10.1 yield=0.68082
# Mannitol 10.2 yield=0.6449672727272727
# Mannitol 100 yield=0.6030575
# Mannitol 100.1 yield=0.6095233333333333
# Mannitol 100.2 yield=0.45442962962962963
# Mannitol 200 yield=0.20479388888888886
# Mannitol 200.1 yield=0.24262
# Mannitol 200.2 yield=0.21631538461538463
# Succinate 10 yield=0.5235373333333333
# Succinate 10.1 yield=0.5116673333333334
# Succinate 10.2 yield=0.5228486666666666
# Succinate 100 yield=0.2778007407407408
# Succinate 100.1 yield=0.1979940740740741
# Succinate 100.2 yield=0.17523111111111112
# Succinate 200 yield=0.7421079365079364
# Succinate 200.1 yield=0.6821497916666667
# Succinate 200.2 yield=0.6533996396396395
# xyl 10 yield=0.5869949999999999
# xyl 10.1 yield=0.6357266666666667
# xyl 10.2 yield=0.6245777777777777
# xyl 100 yield=0.497661981981982
# xyl 100.1 yield=0.5704826666666667
# xyl 100.2 yield=0.5534776068376068
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# DLmalate 10 yield=0.2882315789473684
# DLmalate 10.1 yield=0.39273723577235775
# DLmalate 10.2 yield=0.2717381699346405
# DLmalate 25 yield=0.03336666666666666
# DLmalate 25.1 yield=0.04369533333333333
# DLmalate 25.2 yield=0.05236933333333334
# DLmalate 50 yield=0.0032833333333333334
# DLmalate 50.1 yield=0.005383333333333332
# DLmalate 50.2 yield=0.0033
# glc 0 yield=0.6601026666666665
# 4 yield=0.5646269135802467
# glc 0.1 yield=0.5234457142857143
# 4.1 yield=0.48391333333333336
# glc 0.2 yield=0.4497126984126984
# 4.2 yield=0.4511133333333333
# glucuronic a 10 yield=0.7285993333333334
# glucuronic a 10.1 yield=0.7426959999999999
# glucuronic a 10.2 yield=0.6198872222222223
# glucuronic a 25 yield=0.6699420512820512
# glucuronic a 25.1 yield=0.6618223999999999
# glucuronic a 25.2 yield=0.6345466666666666
# glucuronic a 50 yield=0.05888222222222223
# glucuronic a 50.1 yield=0.02453611111111111
# glucuronic a 50.2 yield=0.029038666666666664
# ketobutyric a 1 yield=0.024093333333333335
# ketobutyric a 1.1 yield=0.024686111111111114
# ketobutyric a 1.2 yield=0.021118888888888892
# ketobutyric a 2 yield=0.023455238095238095
# ketobutyric a 2.1 yield=0.1546
# ketobutyric a 2.2 yield=0.11135111111111111
# ketobutyric a 5 yield=0.2193793939393939
# ketobutyric a 5.1 yield=0.21333629629629625
# ketobutyric a 5.2 yield=0.21374598290598293
# Llactate 10 yield=0.6003355555555554
# Llactate 10.1 yield=0.5647559999999999
# Llactate 10.2 yield=0.6440470175438596
# Llactate 25 yield=0.12207633333333331
# Llactate 25.1 yield=0.11286740740740742
# Llactate 25.2 yield=0.09986633333333332
# Llactate 5 yield=0.005133333333333332
# Llactate 5.1 yield=0.00398333333333333
# Llactate 5.2 yield=0.007383333333333335
# M9 yield=0.1809192307692308
# M9.1 yield=0.26660249999999996
# M9.2 yield=0.1808880833333333
# methyl pyr 10 yield=0.5010153333333334
# methyl pyr 10.1 yield=0.5134703030303029
# methyl pyr 10.2 yield=0.508109090909091
# methyl pyr 25 yield=0.12128142857142855
# methyl pyr 25.1 yield=0.11375444444444444
# methyl pyr 25.2 yield=0.09740579710144924
# methyl pyr 5 yield=0.06034733333333332
# methyl pyr 5.1 yield=0.04323958333333333
# methyl pyr 5.2 yield=0.06655809523809524
# Saccharic ac 0 yield=0.6427627777777777
# 9 yield=0.5968379487179487
# Saccharic ac 0.1 yield=0.6174638888888889
# 9.1 yield=0.4264903703703704
# Saccharic ac 0.2 yield=0.3977622222222222
# 9.2 yield=0.3732160000000001
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# Fru10 yield=0.5916855555555555
# Fru10.1 yield=0.6085788888888888
# Fru10.2 yield=0.6196177777777777
# Fru100 yield=0.6776466666666666
# Fru100.1 yield=0.6140166666666667
# Fru100.2 yield=0.5767183333333332
# Fru200 yield=0.48379878787878794
# Fru200.1 yield=0.5128166666666666
# Fru200.2 yield=0.5206051851851852
# Fum 10 yield=0.44661500000000004
# Fum 10.1 yield=0.4429133333333333
# Fum 10.2 yield=0.47206444444444445
# Fum 100 yield=0.15691666666666665
# Fum 100.1 yield=0.17738666666666666
# Fum 100.2 yield=0.16310666666666665
# Fum 200 yield=0.022612549019607842
# Fum 200.1 yield=1.2355
# Fum 200.2 yield=0.026977272727272728
# Glc 0 yield=0.49270011111111117
# 4 yield=0.7795688172043009
# Glc 0.1 yield=0.7658755555555555
# 4.1 yield=0.4420490196078432
# Glc 0.2 yield=0.4330478431372549
# 4.2 yield=0.4752871794871796
# Glu 10 yield=0.7760707692307693
# Glu 10.1 yield=0.7565368888888888
# Glu 10.2 yield=0.7499090476190474
# Glu 100 yield=0.6495763888888889
# Glu 100.1 yield=0.6536445333333333
# Glu 100.2 yield=0.6548485416666666
# Glu 200 yield=0.4209630000000001
# Glu 200.1 yield=0.404071282051282
# Glu 200.2 yield=0.40440358974358975
# Gly 10 yield=0.5619206451612903
# Gly 10.1 yield=0.503052761904762
# Gly 10.2 yield=0.583627619047619
# Gly 100 yield=0.4599745977011494
# Gly 100.1 yield=0.4943620238095239
# Gly 100.2 yield=0.5138586206896553
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# M9 yield=0.04512055555555555
# M9.1 yield=0.041959393939393935
# M9.2 yield=0.03849533333333334
# pro 10 yield=0.027659629629629628
# pro 10.1 yield=0.026131515151515152
# pro 10.2 yield=0.028797499999999997
# pro 100 yield=0.03726866666666667
# pro 100.1 yield=0.043609999999999996
# pro 100.2 yield=0.043911851851851855
# pro 200 yield=0.5727866666666667
# pro 200.1 yield=0.5617090909090908
# pro 200.2 yield=0.5719138888888888
# tre 10 yield=0.38493272727272737
# tre 10.1 yield=0.39818533333333334
# tre 10.2 yield=0.39431151515151514
# tre 100 yield=0.2913537777777778
# tre 100.1 yield=0.2978112820512821
# tre 100.2 yield=0.31591925925925923
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# galactose 10 yield=0.6879276190476189
# galactose 10.1 yield=0.6222
# galactose 10.2 yield=0.6780866666666667
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# nan Found in array, replaced by mean value of the rest
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-e9b37abf538b> in <module>()
#      54         start_positive = getPostiveStart(sOD)
#      55         if start_positive > 0:
# ---> 56             print fn,'found negative od ', start_positive
#      57         lag_phase_pre = time_max_dODdt - np.log(OD_exp/sOD[start_positive])/pre_max_v
#      58         m = t < lag_phase_pre
#
# NameError: name 'fn' is not defined

# %%
x = t_k

y = sOD_log

plt.plot(x,y,label='log(OD)')

plt.plot(x,y,small_t,tan,'--r',label='log(OD)')

plt.title(name)

plt.xlabel("time")

w = coef_OD

plt.plot(x, w,label='dOD/dt/OD') # can c
# Out:
# Error in callback <function post_execute at 0x7f3d2be71a28> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in post_execute()
#     147             def post_execute():
#     148                 if matplotlib.is_interactive():
# --> 149                     draw_all()
#     150
#     151             # IPython >= 2
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/_pylab_helpers.pyc in draw_all(cls, force)
#     134         for f_mgr in cls.get_all_fig_managers():
#     135             if force or f_mgr.canvas.figure.stale:
# --> 136                 f_mgr.canvas.draw_idle()
#     137
#     138 atexit.register(Gcf.destroy_all)
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in draw_idle(self, *args, **kwargs)
#    2053         if not self._is_idle_drawing:
#    2054             with self._idle_draw_cntx():
# -> 2055                 self.draw(*args, **kwargs)
#    2056
#    2057     def draw_cursor(self, event):
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in draw(self)
#     435             # if toolbar:
#     436             #     toolbar.set_cursor(cursors.WAIT)
# --> 437             self.figure.draw(self.renderer)
#     438             # A GUI class may be need to update a window using this draw, so
#     439             # don't forget to call the superclass.
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/figure.pyc in draw(self, renderer)
#    1491
#    1492             mimage._draw_list_compositing_images(
# -> 1493                 renderer, self, artists, self.suppressComposite)
#    1494
#    1495             renderer.close_group('figure')
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/image.pyc in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in draw(self, renderer, inframe)
#    2633             renderer.stop_rasterizing()
#    2634
# -> 2635         mimage._draw_list_compositing_images(renderer, self, artists)
#    2636
#    2637         renderer.close_group('axes')
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/image.pyc in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/text.pyc in draw(self, renderer)
#     704
#     705         with _wrap_text(self) as textobj:
# --> 706             bbox, info, descent = textobj._get_layout(renderer)
#     707             trans = textobj.get_transform()
#     708
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/text.pyc in _get_layout(self, renderer)
#     303         baseline = 0
#     304         for i, line in enumerate(lines):
# --> 305             clean_line, ismath = self.is_math_text(line, self.get_usetex())
#     306             if clean_line:
#     307                 w, h, d = renderer.get_text_width_height_descent(clean_line,
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/text.pyc in is_math_text(s, usetex)
#    1186             return s, 'TeX'
#    1187
# -> 1188         if cbook.is_math_text(s):
#    1189             return s, True
#    1190         else:
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/cbook/__init__.pyc in is_math_text(s)
#    2033     except UnicodeDecodeError:
#    2034         raise ValueError(
# -> 2035             "matplotlib display text must have all code points < 128 or use "
#    2036             "Unicode strings")
#    2037
#
# ValueError: matplotlib display text must have all code points < 128 or use Unicode strings
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/xsong/miniconda2/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     245
#     246     if 'png' in formats:
# --> 247         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     248     if 'retina' in formats or 'png2x' in formats:
#     249         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     129
#     130     bytes_io = BytesIO()
# --> 131     fig.canvas.print_figure(bytes_io, **kw)
#     132     data = bytes_io.getvalue()
#     133     if fmt == 'svg':
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2210                     orientation=orientation,
#    2211                     dryrun=True,
# -> 2212                     **kwargs)
#    2213                 renderer = self.figure._cachedRenderer
#    2214                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     515
#     516     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 517         FigureCanvasAgg.draw(self)
#     518         renderer = self.get_renderer()
#     519         original_dpi = renderer.dpi
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in draw(self)
#     435             # if toolbar:
#     436             #     toolbar.set_cursor(cursors.WAIT)
# --> 437             self.figure.draw(self.renderer)
#     438             # A GUI class may be need to update a window using this draw, so
#     439             # don't forget to call the superclass.
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/figure.pyc in draw(self, renderer)
#    1491
#    1492             mimage._draw_list_compositing_images(
# -> 1493                 renderer, self, artists, self.suppressComposite)
#    1494
#    1495             renderer.close_group('figure')
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/image.pyc in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in draw(self, renderer, inframe)
#    2633             renderer.stop_rasterizing()
#    2634
# -> 2635         mimage._draw_list_compositing_images(renderer, self, artists)
#    2636
#    2637         renderer.close_group('axes')
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/image.pyc in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/text.pyc in draw(self, renderer)
#     704
#     705         with _wrap_text(self) as textobj:
# --> 706             bbox, info, descent = textobj._get_layout(renderer)
#     707             trans = textobj.get_transform()
#     708
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/text.pyc in _get_layout(self, renderer)
#     303         baseline = 0
#     304         for i, line in enumerate(lines):
# --> 305             clean_line, ismath = self.is_math_text(line, self.get_usetex())
#     306             if clean_line:
#     307                 w, h, d = renderer.get_text_width_height_descent(clean_line,
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/text.pyc in is_math_text(s, usetex)
#    1186             return s, 'TeX'
#    1187
# -> 1188         if cbook.is_math_text(s):
#    1189             return s, True
#    1190         else:
#
# /home/xsong/miniconda2/lib/python2.7/site-packages/matplotlib/cbook/__init__.pyc in is_math_text(s)
#    2033     except UnicodeDecodeError:
#    2034         raise ValueError(
# -> 2035             "matplotlib display text must have all code points < 128 or use "
#    2036             "Unicode strings")
#    2037
#
# ValueError: matplotlib display text must have all code points < 128 or use Unicode strings

# %% [markdown]
# # Load csv

# %%
import os
import pandas as pd

def getfiles(folderPath):
    pths = []
    for root, dirs, files in os.walk(folderPath):
        for fn in files:            
            if fn.endswith('.csv') and 'stats' in fn:
                pth = os.path.join(root, fn)
                pths.append(pth)
    return pths

pths = getfiles('csv')

extrac_gr = "Growth Rate"
extrac_yi = "yield"

yield_list = []
growth_rate_list = []
name_list = []
for path in pths:
    print path
    data = pd.read_csv(path)
    data2 = data.set_index(data.columns[0])
    pre_strain ='no'
    for strain in data2.index:
        if pre_strain not in strain:
            try:
                if pre_strain != 'no':
                    print "s3",pre_strain
                    yield_list.append(yield_dict)
                    growth_rate_list.append(growth_dict)
                    name_list.append(pre_strain)
            except:
                print pre_strain,strain

        if pre_strain != strain:
            if pre_strain not in strain:
                pre_strain = strain
                #name_list.append(pre_strain)
                #print "s1",pre_strain, strain
                i = 1
                yield_dict = dict()
                growth_dict = dict()

        init = 'R'+str(i)
        if pre_strain in strain:
            #print "s2",pre_strain, strain
            #print init,data2.loc[strain,extrac]
            yield_dict[init] = data2.loc[strain,extrac_yi]
            growth_dict[init] = data2.loc[strain, extrac_gr]
            i = i +1


print "last s3",pre_strain
yield_list.append(yield_dict)
growth_rate_list.append(growth_dict)
name_list.append(pre_strain)
# Out:
# csv/MG1655 10082019 N-stats.csv
# s2 agaV agaV
# s2 agaV agaV.1
# s2 agaV agaV.2
# s2 agaV agaV.3
# s2 agaV agaV.4
# s2 agaV agaV.5
# s2 agaV agaV.6
# s2 agaV agaV.7
# s3 agaV
# s2 gltK gltK
# s2 gltK gltK.1
# s2 gltK gltK.2
# s2 gltK gltK.3
# s2 gltK gltK.4
# s2 gltK gltK.5
# s2 gltK gltK.6
# s2 gltK gltK.7
# s3 gltK
# s2 gspF gspF
# s2 gspF gspF.1
# s2 gspF gspF.2
# s2 gspF gspF.3
# s2 gspF gspF.4
# s2 gspF gspF.5
# s2 gspF gspF.6
# s2 gspF gspF.7
# s3 gspF
# s2 mtlD mtlD
# s2 mtlD mtlD.1
# s2 mtlD mtlD.2
# s2 mtlD mtlD.3
# s2 mtlD mtlD.4
# s2 mtlD mtlD.5
# s2 mtlD mtlD.6
# s2 mtlD mtlD.7
# s3 mtlD
# s2 rarD rarD
# s2 rarD rarD.1
# s2 rarD rarD.2
# s2 rarD rarD.3
# s2 rarD rarD.4
# s2 rarD rarD.5
# s2 rarD rarD.6
# s2 rarD rarD.7
# s3 rarD
# s2 rsd rsd
# s2 rsd rsd.1
# s2 rsd rsd.2
# s2 rsd rsd.3
# s2 rsd rsd.4
# s2 rsd rsd.5
# s2 rsd rsd.6
# s2 rsd rsd.7
# s3 rsd
# s2 uxaB uxaB
# s2 uxaB uxaB.1
# s2 uxaB uxaB.2
# s2 uxaB uxaB.3
# s2 uxaB uxaB.4
# s2 uxaB uxaB.5
# s2 uxaB uxaB.6
# s2 uxaB uxaB.7
# s3 uxaB
# s2 WT WT
# s2 WT WT.1
# s2 WT WT.2
# s2 WT WT.3
# s2 WT WT.4
# s2 WT WT.5
# s2 WT WT.6
# s2 WT WT.7
# s3 WT
# s2 yagS yagS
# s2 yagS yagS.1
# s2 yagS yagS.2
# s2 yagS yagS.3
# s2 yagS yagS.4
# s2 yagS yagS.5
# s2 yagS yagS.6
# s2 yagS yagS.7
# s3 yagS
# s2 zapE zapE
# s2 zapE zapE.1
# s2 zapE zapE.2
# s2 zapE zapE.3
# s2 zapE zapE.4
# s2 zapE zapE.5
# s2 zapE zapE.6
# s2 zapE zapE.7
# csv/MG1655 25062019-stats.csv
# s2 atos atos
# s2 atos atos.1
# s2 atos atos.2
# s2 atos atos.3
# s2 atos atos.4
# s2 atos atos.5
# s2 atos atos.6
# s2 atos atos.7
# s3 atos
# s2 bglF bglF
# s2 bglF bglF.1
# s2 bglF bglF.2
# s2 bglF bglF.3
# s2 bglF bglF.4
# s2 bglF bglF.5
# s2 bglF bglF.6
# s2 bglF bglF.7
# s3 bglF
# s2 dcuA dcuA
# s2 dcuA dcuA.1
# s2 dcuA dcuA.2
# s2 dcuA dcuA.3
# s2 dcuA dcuA.4
# s2 dcuA dcuA.5
# s2 dcuA dcuA.6
# s2 dcuA dcuA.7
# s3 dcuA
# s2 eptA eptA
# s2 eptA eptA.1
# s2 eptA eptA.2
# s2 eptA eptA.3
# s2 eptA eptA.4
# s2 eptA eptA.5
# s2 eptA eptA.6
# s2 eptA eptA.7
# s3 eptA
# s2 eutQ eutQ
# s2 eutQ eutQ.1
# s2 eutQ eutQ.2
# s2 eutQ eutQ.3
# s2 eutQ eutQ.4
# s2 eutQ eutQ.5
# s2 eutQ eutQ.6
# s2 eutQ eutQ.7
# s3 eutQ
# s2 flgD flgD
# s2 flgD flgD.1
# s2 flgD flgD.2
# s2 flgD flgD.3
# s2 flgD flgD.4
# s2 flgD flgD.5
# s2 flgD flgD.6
# s2 flgD flgD.7
# s3 flgD
# s2 glf glf
# s2 glf glf.1
# s2 glf glf.2
# s2 glf glf.3
# s2 glf glf.4
# s2 glf glf.5
# s2 glf glf.6
# s2 glf glf.7
# s3 glf
# s2 gltL gltL
# s2 gltL gltL.1
# s2 gltL gltL.2
# s2 gltL gltL.3
# s2 gltL gltL.4
# s2 gltL gltL.5
# s2 gltL gltL.6
# s2 gltL gltL.7
# s3 gltL
# s2 gnsA gnsA
# s2 gnsA gnsA.1
# s2 gnsA gnsA.2
# s2 gnsA gnsA.3
# s2 gnsA gnsA.4
# s2 gnsA gnsA.5
# s2 gnsA gnsA.6
# s2 gnsA gnsA.7
# s3 gnsA
# s2 WT WT
# s2 WT WT.1
# s2 WT WT.2
# s2 WT WT.3
# s2 WT WT.4
# s2 WT WT.5
# s2 WT WT.6
# s2 WT WT.7
# csv/MG1655 22062019-stats.csv
# s2 cstA cstA
# s2 cstA cstA.1
# s2 cstA cstA.2
# s2 cstA cstA.3
# s2 cstA cstA.4
# s2 cstA cstA.5
# s2 cstA cstA.6
# s2 cstA cstA.7
# s3 cstA
# s2 dcp dcp
# s2 dcp dcp.1
# s2 dcp dcp.2
# s2 dcp dcp.3
# s2 dcp dcp.4
# s2 dcp dcp.5
# s2 dcp dcp.6
# s2 dcp dcp.7
# s3 dcp
# s2 gltD gltD
# s2 gltD gltD.1
# s2 gltD gltD.2
# s2 gltD gltD.3
# s2 gltD gltD.4
# s2 gltD gltD.5
# s2 gltD gltD.6
# s2 gltD gltD.7
# s3 gltD
# s2 mprA mprA
# s2 mprA mprA.1
# s2 mprA mprA.2
# s2 mprA mprA.3
# s2 mprA mprA.4
# s2 mprA mprA.5
# s2 mprA mprA.6
# s2 mprA mprA.7
# s3 mprA
# s2 norW norW
# s2 norW norW.1
# s2 norW norW.2
# s2 norW norW.3
# s2 norW norW.4
# s2 norW norW.5
# s2 norW norW.6
# s2 norW norW.7
# s3 norW
# s2 tyrB tyrB
# s2 tyrB tyrB.1
# s2 tyrB tyrB.2
# s2 tyrB tyrB.3
# s2 tyrB tyrB.4
# s2 tyrB tyrB.5
# s2 tyrB tyrB.6
# s2 tyrB tyrB.7
# s3 tyrB
# s2 WT WT
# s2 WT WT.1
# s2 WT WT.2
# s2 WT WT.3
# s2 WT WT.4
# s2 WT WT.5
# s2 WT WT.6
# s2 WT WT.7
# s3 WT
# s2 yggE yggE
# s2 yggE yggE.1
# s2 yggE yggE.2
# s2 yggE yggE.3
# s2 yggE yggE.4
# s2 yggE yggE.5
# s2 yggE yggE.6
# s2 yggE yggE.7
# s3 yggE
# s2 yicH yicH
# s2 yicH yicH.1
# s2 yicH yicH.2
# s2 yicH yicH.3
# s2 yicH yicH.4
# s2 yicH yicH.5
# s2 yicH yicH.6
# s2 yicH yicH.7
# s3 yicH
# s2 yicM yicM
# s2 yicM yicM.1
# s2 yicM yicM.2
# s2 yicM yicM.3
# s2 yicM yicM.4
# s2 yicM yicM.5
# s2 yicM yicM.6
# s2 yicM yicM.7
# csv/MG1655 14082019 N-stats.csv
# s2 appY appY
# s2 appY appY.1
# s2 appY appY.2
# s2 appY appY.3
# s2 appY appY.4
# s2 appY appY.5
# s2 appY appY.6
# s2 appY appY.7
# s3 appY
# s2 gspL gspL
# s2 gspL gspL.1
# s2 gspL gspL.2
# s2 gspL gspL.3
# s2 gspL gspL.4
# s2 gspL gspL.5
# s2 gspL gspL.6
# s2 gspL gspL.7
# s3 gspL
# s2 lsrc lsrc
# s2 lsrc lsrc.1
# s2 lsrc lsrc.2
# s2 lsrc lsrc.3
# s2 lsrc lsrc.4
# s2 lsrc lsrc.5
# s2 lsrc lsrc.6
# s2 lsrc lsrc.7
# s3 lsrc
# s2 ompL ompL
# s2 ompL ompL.1
# s2 ompL ompL.2
# s2 ompL ompL.3
# s2 ompL ompL.4
# s2 ompL ompL.5
# s2 ompL ompL.6
# s2 ompL ompL.7
# s3 ompL
# s2 WT WT
# s2 WT WT.1
# s2 WT WT.2
# s2 WT WT.3
# s2 WT WT.4
# s2 WT WT.5
# s2 WT WT.6
# s2 WT WT.7
# s3 WT
# s2 ycaL ycaL
# s2 ycaL ycaL.1
# s2 ycaL ycaL.2
# s2 ycaL ycaL.3
# s2 ycaL ycaL.4
# s2 ycaL ycaL.5
# s2 ycaL ycaL.6
# s2 ycaL ycaL.7
# s3 ycaL
# s2 yfiD yfiD
# s2 yfiD yfiD.1
# s2 yfiD yfiD.2
# s2 yfiD yfiD.3
# s2 yfiD yfiD.4
# s2 yfiD yfiD.5
# s2 yfiD yfiD.6
# s2 yfiD yfiD.7
# s3 yfiD
# s2 yhbP yhbP
# s2 yhbP yhbP.1
# s2 yhbP yhbP.2
# s2 yhbP yhbP.3
# s2 yhbP yhbP.4
# s2 yhbP yhbP.5
# s2 yhbP yhbP.6
# s2 yhbP yhbP.7
# s3 yhbP
# s2 yjfJ yjfJ
# s2 yjfJ yjfJ.1
# s2 yjfJ yjfJ.2
# s2 yjfJ yjfJ.3
# s2 yjfJ yjfJ.4
# s2 yjfJ yjfJ.5
# s2 yjfJ yjfJ.6
# s2 yjfJ yjfJ.7
# s3 yjfJ
# s2 yjfL yjfL
# s2 yjfL yjfL.1
# s2 yjfL yjfL.2
# s2 yjfL yjfL.3
# s2 yjfL yjfL.4
# s2 yjfL yjfL.5
# s2 yjfL yjfL.6
# s2 yjfL yjfL.7
# csv/MG1655 20082019 N-stats.csv
# s2 ptsH ptsH
# s2 ptsH ptsH.1
# s2 ptsH ptsH.2
# s2 ptsH ptsH.3
# s2 ptsH ptsH.4
# s2 ptsH ptsH.5
# s2 ptsH ptsH.6
# s2 ptsH ptsH.7
# s3 ptsH
# s2 WT WT
# s2 WT WT.1
# s2 WT WT.2
# s2 WT WT.3
# s2 WT WT.4
# s2 WT WT.5
# s2 WT WT.6
# s2 WT WT.7
# s3 WT
# s2 ygjP ygjP
# s2 ygjP ygjP.1
# s2 ygjP ygjP.2
# s2 ygjP ygjP.3
# s2 ygjP ygjP.4
# s2 ygjP ygjP.5
# s2 ygjP ygjP.6
# s2 ygjP ygjP.7
# s3 ygjP
# s2 yigZ yigZ
# s2 yigZ yigZ.1
# s2 yigZ yigZ.2
# s2 yigZ yigZ.3
# s2 yigZ yigZ.4
# s2 yigZ yigZ.5
# s2 yigZ yigZ.6
# s2 yigZ yigZ.7
# s3 yigZ
# s2 ykfF ykfF
# s2 ykfF ykfF.1
# s2 ykfF ykfF.2
# s2 ykfF ykfF.3
# s2 ykfF ykfF.4
# s2 ykfF ykfF.5
# s2 ykfF ykfF.6
# s2 ykfF ykfF.7
# s3 ykfF
# s2 yobH yobH
# s2 yobH yobH.1
# s2 yobH yobH.2
# s2 yobH yobH.3
# s2 yobH yobH.4
# s2 yobH yobH.5
# s2 yobH yobH.6
# s2 yobH yobH.7
# s3 yobH
# s2 yphG yphG
# s2 yphG yphG.1
# s2 yphG yphG.2
# s2 yphG yphG.3
# s2 yphG yphG.4
# s2 yphG yphG.5
# s2 yphG yphG.6
# s2 yphG yphG.7
# s3 yphG
# s2 yqjE yqjE
# s2 yqjE yqjE.1
# s2 yqjE yqjE.2
# s2 yqjE yqjE.3
# s2 yqjE yqjE.4
# s2 yqjE yqjE.5
# s2 yqjE yqjE.6
# s2 yqjE yqjE.7
# s3 yqjE
# s2 Unnamed: 65 Unnamed: 65
# s3 Unnamed: 65
# s2 Unnamed: 66 Unnamed: 66
# s3 Unnamed: 66
# s2 Unnamed: 67 Unnamed: 67
# s3 Unnamed: 67
# s2 Unnamed: 68 Unnamed: 68
# s3 Unnamed: 68
# s2 Unnamed: 69 Unnamed: 69
# s3 Unnamed: 69
# s2 Unnamed: 70 Unnamed: 70
# s3 Unnamed: 70
# s2 Unnamed: 71 Unnamed: 71
# s3 Unnamed: 71
# s2 Unnamed: 72 Unnamed: 72
# s3 Unnamed: 72
# s2 Unnamed: 73 Unnamed: 73
# s3 Unnamed: 73
# s2 Unnamed: 74 Unnamed: 74
# s3 Unnamed: 74
# s2 Unnamed: 75 Unnamed: 75
# s3 Unnamed: 75
# s2 Unnamed: 76 Unnamed: 76
# s3 Unnamed: 76
# s2 Unnamed: 77 Unnamed: 77
# s3 Unnamed: 77
# s2 Unnamed: 78 Unnamed: 78
# s3 Unnamed: 78
# s2 Unnamed: 79 Unnamed: 79
# s3 Unnamed: 79
# s2 Unnamed: 80 Unnamed: 80
# csv/MG1655 23062019-stats.csv
# s2 cstA cstA
# s2 cstA cstA.1
# s2 cstA cstA.2
# s2 cstA cstA.3
# s2 cstA cstA.4
# s2 cstA cstA.5
# s2 cstA cstA.6
# s2 cstA cstA.7
# s3 cstA
# s2 idnD idnD
# s2 idnD idnD.1
# s2 idnD idnD.2
# s2 idnD idnD.3
# s2 idnD idnD.4
# s2 idnD idnD.5
# s2 idnD idnD.6
# s2 idnD idnD.7
# s3 idnD
# s2 intG intG
# s2 intG intG.1
# s2 intG intG.2
# s2 intG intG.3
# s2 intG intG.4
# s2 intG intG.5
# s2 intG intG.6
# s2 intG intG.7
# s3 intG
# s2 mprA mprA
# s2 mprA mprA.1
# s2 mprA mprA.2
# s2 mprA mprA.3
# s2 mprA mprA.4
# s2 mprA mprA.5
# s2 mprA mprA.6
# s2 mprA mprA.7
# s3 mprA
# s2 narD narD
# s2 narD narD.1
# s2 narD narD.2
# s2 narD narD.3
# s2 narD narD.4
# s2 narD narD.5
# s2 narD narD.6
# s2 narD narD.7
# s3 narD
# s2 norV norV
# s2 norV norV.1
# s2 norV norV.2
# s2 norV norV.3
# s2 norV norV.4
# s2 norV norV.5
# s2 norV norV.6
# s2 norV norV.7
# s3 norV
# s2 tyrB tyrB
# s2 tyrB tyrB.1
# s2 tyrB tyrB.2
# s2 tyrB tyrB.3
# s2 tyrB tyrB.4
# s2 tyrB tyrB.5
# s2 tyrB tyrB.6
# s2 tyrB tyrB.7
# s3 tyrB
# s2 WT WT
# s2 WT WT.1
# s2 WT WT.2
# s2 WT WT.3
# s2 WT WT.4
# s2 WT WT.5
# s2 WT WT.6
# s2 WT WT.7
# s3 WT
# s2 yeeW yeeW
# s2 yeeW yeeW.1
# s2 yeeW yeeW.2
# s2 yeeW yeeW.3
# s2 yeeW yeeW.4
# s2 yeeW yeeW.5
# s2 yeeW yeeW.6
# s2 yeeW yeeW.7
# s3 yeeW
# s2 ygfO ygfO
# s2 ygfO ygfO.1
# s2 ygfO ygfO.2
# s2 ygfO ygfO.3
# s2 ygfO ygfO.4
# s2 ygfO ygfO.5
# s2 ygfO ygfO.6
# s2 ygfO ygfO.7
# csv/MG1655 17082019 N-stats.csv
# s2 alsB alsB
# s2 alsB alsB.1
# s2 alsB alsB.2
# s2 alsB alsB.3
# s2 alsB alsB.4
# s2 alsB alsB.5
# s2 alsB alsB.6
# s2 alsB alsB.7
# s3 alsB
# s2 ascG ascG
# s2 ascG ascG.1
# s2 ascG ascG.2
# s2 ascG ascG.3
# s2 ascG ascG.4
# s2 ascG ascG.5
# s2 ascG ascG.6
# s2 ascG ascG.7
# s3 ascG
# s2 pflD pflD
# s2 pflD pflD.1
# s2 pflD pflD.2
# s2 pflD pflD.3
# s2 pflD pflD.4
# s2 pflD pflD.5
# s2 pflD pflD.6
# s2 pflD pflD.7
# s3 pflD
# s2 treC treC
# s2 treC treC.1
# s2 treC treC.2
# s2 treC treC.3
# s2 treC treC.4
# s2 treC treC.5
# s2 treC treC.6
# s2 treC treC.7
# s3 treC
# s2 WT WT
# s2 WT WT.1
# s2 WT WT.2
# s2 WT WT.3
# s2 WT WT.4
# s2 WT WT.5
# s2 WT WT.6
# s2 WT WT.7
# s3 WT
# s2 xdhC xdhC
# s2 xdhC xdhC.1
# s2 xdhC xdhC.2
# s2 xdhC xdhC.3
# s2 xdhC xdhC.4
# s2 xdhC xdhC.5
# s2 xdhC xdhC.6
# s2 xdhC xdhC.7
# s3 xdhC
# s2 yggF yggF
# s2 yggF yggF.1
# s2 yggF yggF.2
# s2 yggF yggF.3
# s2 yggF yggF.4
# s2 yggF yggF.5
# s2 yggF yggF.6
# s2 yggF yggF.7
# s3 yggF
# s2 yihV yihV
# s2 yihV yihV.1
# s2 yihV yihV.2
# s2 yihV yihV.3
# s2 yihV yihV.4
# s2 yihV yihV.5
# s2 yihV yihV.6
# s2 yihV yihV.7
# s3 yihV
# s2 yjeL yjeL
# s2 yjeL yjeL.1
# s2 yjeL yjeL.2
# s2 yjeL yjeL.3
# s2 yjeL yjeL.4
# s2 yjeL yjeL.5
# s2 yjeL yjeL.6
# s2 yjeL yjeL.7
# s3 yjeL
# s2 yjfF yjfF
# s2 yjfF yjfF.1
# s2 yjfF yjfF.2
# s2 yjfF yjfF.3
# s2 yjfF yjfF.4
# s2 yjfF yjfF.5
# s2 yjfF yjfF.6
# s2 yjfF yjfF.7
# csv/MG1655 13082019 N-stats.csv
# s2 citT citT
# s2 citT citT.1
# s2 citT citT.2
# s2 citT citT.3
# s2 citT citT.4
# s2 citT citT.5
# s2 citT citT.6
# s2 citT citT.7
# s3 citT
# s2 WT WT
# s2 WT WT.1
# s2 WT WT.2
# s2 WT WT.3
# s2 WT WT.4
# s2 WT WT.5
# s2 WT WT.6
# s2 WT WT.7
# s3 WT
# s2 xdhC xdhC
# s2 xdhC xdhC.1
# s2 xdhC xdhC.2
# s2 xdhC xdhC.3
# s2 xdhC xdhC.4
# s2 xdhC xdhC.5
# s2 xdhC xdhC.6
# s2 xdhC xdhC.7
# s3 xdhC
# s2 ybdG ybdG
# s2 ybdG ybdG.1
# s2 ybdG ybdG.2
# s2 ybdG ybdG.3
# s2 ybdG ybdG.4
# s2 ybdG ybdG.5
# s2 ybdG ybdG.6
# s2 ybdG ybdG.7
# s3 ybdG
# s2 ycfX ycfX
# s2 ycfX ycfX.1
# s2 ycfX ycfX.2
# s2 ycfX ycfX.3
# s2 ycfX ycfX.4
# s2 ycfX ycfX.5
# s2 ycfX ycfX.6
# s2 ycfX ycfX.7
# s3 ycfX
# s2 yifL yifL
# s2 yifL yifL.1
# s2 yifL yifL.2
# s2 yifL yifL.3
# s2 yifL yifL.4
# s2 yifL yifL.5
# s2 yifL yifL.6
# s2 yifL yifL.7
# s3 yifL
# s2 yjfJ yjfJ
# s2 yjfJ yjfJ.1
# s2 yjfJ yjfJ.2
# s2 yjfJ yjfJ.3
# s2 yjfJ yjfJ.4
# s2 yjfJ yjfJ.5
# s2 yjfJ yjfJ.6
# s2 yjfJ yjfJ.7
# s3 yjfJ
# s2 ykfI ykfI
# s2 ykfI ykfI.1
# s2 ykfI ykfI.2
# s2 ykfI ykfI.3
# s2 ykfI ykfI.4
# s2 ykfI ykfI.5
# s2 ykfI ykfI.6
# s2 ykfI ykfI.7
# s3 ykfI
# s2 ytfF ytfF
# s2 ytfF ytfF.1
# s2 ytfF ytfF.2
# s2 ytfF ytfF.3
# s2 ytfF ytfF.4
# s2 ytfF ytfF.5
# s2 ytfF ytfF.6
# s2 ytfF ytfF.7
# s3 ytfF
# s2 ytfL ytfL
# s2 ytfL ytfL.1
# s2 ytfL ytfL.2
# s2 ytfL ytfL.3
# s2 ytfL ytfL.4
# s2 ytfL ytfL.5
# s2 ytfL ytfL.6
# s2 ytfL ytfL.7
# csv/MG1655 24062019-stats.csv
# s2 caiB caiB
# s2 caiB caiB.1
# s2 caiB caiB.2
# s2 caiB caiB.3
# s2 caiB caiB.4
# s2 caiB caiB.5
# s2 caiB caiB.6
# s2 caiB caiB.7
# s3 caiB
# s2 gspM gspM
# s2 gspM gspM.1
# s2 gspM gspM.2
# s2 gspM gspM.3
# s2 gspM gspM.4
# s2 gspM gspM.5
# s2 gspM gspM.6
# s2 gspM gspM.7
# s3 gspM
# s2 melA melA
# s2 melA melA.1
# s2 melA melA.2
# s2 melA melA.3
# s2 melA melA.4
# s2 melA melA.5
# s2 melA melA.6
# s2 melA melA.7
# s3 melA
# s2 syd syd
# s2 syd syd.1
# s2 syd syd.2
# s2 syd syd.3
# s2 syd syd.4
# s2 syd syd.5
# s2 syd syd.6
# s2 syd syd.7
# s3 syd
# s2 WT WT
# s2 WT WT.1
# s2 WT WT.2
# s2 WT WT.3
# s2 WT WT.4
# s2 WT WT.5
# s2 WT WT.6
# s2 WT WT.7
# s3 WT
# s2 ybaJ ybaJ
# s2 ybaJ ybaJ.1
# s2 ybaJ ybaJ.2
# s2 ybaJ ybaJ.3
# s2 ybaJ ybaJ.4
# s2 ybaJ ybaJ.5
# s2 ybaJ ybaJ.6
# s2 ybaJ ybaJ.7
# s3 ybaJ
# s2 ydjK ydjK
# s2 ydjK ydjK.1
# s2 ydjK ydjK.2
# s2 ydjK ydjK.3
# s2 ydjK ydjK.4
# s2 ydjK ydjK.5
# s2 ydjK ydjK.6
# s2 ydjK ydjK.7
# s3 ydjK
# s2 yhbW yhbW
# s2 yhbW yhbW.1
# s2 yhbW yhbW.2
# s2 yhbW yhbW.3
# s2 yhbW yhbW.4
# s2 yhbW yhbW.5
# s2 yhbW yhbW.6
# s2 yhbW yhbW.7
# s3 yhbW
# s2 yhcM yhcM
# s2 yhcM yhcM.1
# s2 yhcM yhcM.2
# s2 yhcM yhcM.3
# s2 yhcM yhcM.4
# s2 yhcM yhcM.5
# s2 yhcM yhcM.6
# s2 yhcM yhcM.7
# s3 yhcM
# s2 yhdX yhdX
# s2 yhdX yhdX.1
# s2 yhdX yhdX.2
# s2 yhdX yhdX.3
# s2 yhdX yhdX.4
# s2 yhdX yhdX.5
# s2 yhdX yhdX.6
# s2 yhdX yhdX.7
# csv/MG1655 19062019-stats.csv
# s2 alr alr
# s2 alr alr.1
# s2 alr alr.2
# s2 alr alr.3
# s2 alr alr.4
# s2 alr alr.5
# s2 alr alr.6
# s2 alr alr.7
# s3 alr
# s2 cbpM cbpM
# s2 cbpM cbpM.1
# s2 cbpM cbpM.2
# s2 cbpM cbpM.3
# s2 cbpM cbpM.4
# s2 cbpM cbpM.5
# s2 cbpM cbpM.6
# s2 cbpM cbpM.7
# s3 cbpM
# s2 fixC fixC
# s2 fixC fixC.1
# s2 fixC fixC.2
# s2 fixC fixC.3
# s2 fixC fixC.4
# s2 fixC fixC.5
# s2 fixC fixC.6
# s2 fixC fixC.7
# s3 fixC
# s2 hybG hybG
# s2 hybG hybG.1
# s2 hybG hybG.2
# s2 hybG hybG.3
# s2 hybG hybG.4
# s2 hybG hybG.5
# s2 hybG hybG.6
# s2 hybG hybG.7
# s3 hybG
# s2 hycA hycA
# s2 hycA hycA.1
# s2 hycA hycA.2
# s2 hycA hycA.3
# s2 hycA hycA.4
# s2 hycA hycA.5
# s2 hycA hycA.6
# s2 hycA hycA.7
# s3 hycA
# s2 nirC nirC
# s2 nirC nirC.1
# s2 nirC nirC.2
# s2 nirC nirC.3
# s2 nirC nirC.4
# s2 nirC nirC.5
# s2 nirC nirC.6
# s2 nirC nirC.7
# s3 nirC
# s2 phnH phnH
# s2 phnH phnH.1
# s2 phnH phnH.2
# s2 phnH phnH.3
# s2 phnH phnH.4
# s2 phnH phnH.5
# s2 phnH phnH.6
# s2 phnH phnH.7
# s3 phnH
# s2 WT WT
# s2 WT WT.1
# s2 WT WT.2
# s2 WT WT.3
# s2 WT WT.4
# s2 WT WT.5
# s2 WT WT.6
# s2 WT WT.7
# s3 WT
# s2 ybda ybda
# s2 ybda ybda.1
# s2 ybda ybda.2
# s2 ybda ybda.3
# s2 ybda ybda.4
# s2 ybda ybda.5
# s2 ybda ybda.6
# s2 ybda ybda.7
# s3 ybda
# s2 ydcP ydcP
# s2 ydcP ydcP.1
# s2 ydcP ydcP.2
# s2 ydcP ydcP.3
# s2 ydcP ydcP.4
# s2 ydcP ydcP.5
# s2 ydcP ydcP.6
# s2 ydcP ydcP.7
# csv/MG1655 07072019-stats.csv
# s2 aqpZ aqpZ
# s2 aqpZ aqpZ.1
# s2 aqpZ aqpZ.2
# s2 aqpZ aqpZ.3
# s2 aqpZ aqpZ.4
# s2 aqpZ aqpZ.5
# s2 aqpZ aqpZ.6
# s2 aqpZ aqpZ.7
# s3 aqpZ
# s2 nsrR nsrR
# s2 nsrR nsrR.1
# s2 nsrR nsrR.2
# s2 nsrR nsrR.3
# s2 nsrR nsrR.4
# s2 nsrR nsrR.5
# s2 nsrR nsrR.6
# s2 nsrR nsrR.7
# s3 nsrR
# s2 ydgT ydgT
# s2 ydgT ydgT.1
# s2 ydgT ydgT.2
# s2 ydgT ydgT.3
# s2 ydgT ydgT.4
# s2 ydgT ydgT.5
# s2 ydgT ydgT.6
# s2 ydgT ydgT.7
# s3 ydgT
# s2 yidH yidH
# s2 yidH yidH.1
# s2 yidH yidH.2
# s2 yidH yidH.3
# s2 yidH yidH.4
# s2 yidH yidH.5
# s2 yidH yidH.6
# s2 yidH yidH.7
# s3 yidH
# s2 ybgD ybgD
# s2 ybgD ybgD.1
# s2 ybgD ybgD.2
# s2 ybgD ybgD.3
# s2 ybgD ybgD.4
# s2 ybgD ybgD.5
# s2 ybgD ybgD.6
# s2 ybgD ybgD.7
# s3 ybgD
# s2 yagH yagH
# s2 yagH yagH.1
# s2 yagH yagH.2
# s2 yagH yagH.3
# s2 yagH yagH.4
# s2 yagH yagH.5
# s2 yagH yagH.6
# s2 yagH yagH.7
# s3 yagH
# s2 yafX yafX
# s2 yafX yafX.1
# s2 yafX yafX.2
# s2 yafX yafX.3
# s2 yafX yafX.4
# s2 yafX yafX.5
# s2 yafX yafX.6
# s2 yafX yafX.7
# s3 yafX
# s2 caiT caiT
# s2 caiT caiT.1
# s2 caiT caiT.2
# s2 caiT caiT.3
# s2 caiT caiT.4
# s2 caiT caiT.5
# s2 caiT caiT.6
# s2 caiT caiT.7
# s3 caiT
# s2 yiaW yiaW
# s2 yiaW yiaW.1
# s2 yiaW yiaW.2
# s2 yiaW yiaW.3
# s2 yiaW yiaW.4
# s2 yiaW yiaW.5
# s2 yiaW yiaW.6
# s2 yiaW yiaW.7
# s3 yiaW
# s2 WT WT
# s2 WT WT.1
# s2 WT WT.2
# s2 WT WT.3
# s2 WT WT.4
# s2 WT WT.5
# s2 WT WT.6
# s2 WT WT.7
# csv/MG1655 29062019-stats.csv
# s2 fruR fruR
# s2 fruR fruR.1
# s2 fruR fruR.2
# s2 fruR fruR.3
# s2 fruR fruR.4
# s2 fruR fruR.5
# s2 fruR fruR.6
# s2 fruR fruR.7
# s3 fruR
# s2 hsIR hsIR
# s2 hsIR hsIR.1
# s2 hsIR hsIR.2
# s2 hsIR hsIR.3
# s2 hsIR hsIR.4
# s2 hsIR hsIR.5
# s2 hsIR hsIR.6
# s2 hsIR hsIR.7
# s3 hsIR
# s2 mhpB mhpB
# s2 mhpB mhpB.1
# s2 mhpB mhpB.2
# s2 mhpB mhpB.3
# s2 mhpB mhpB.4
# s2 mhpB mhpB.5
# s2 mhpB mhpB.6
# s2 mhpB mhpB.7
# s3 mhpB
# s2 tdcE tdcE
# s2 tdcE tdcE.1
# s2 tdcE tdcE.2
# s2 tdcE tdcE.3
# s2 tdcE tdcE.4
# s2 tdcE tdcE.5
# s2 tdcE tdcE.6
# s2 tdcE tdcE.7
# s3 tdcE
# s2 WT WT
# s2 WT WT.1
# s2 WT WT.2
# s2 WT WT.3
# s2 WT WT.4
# s2 WT WT.5
# s2 WT WT.6
# s2 WT WT.7
# s3 WT
# s2 ydjQ ydjQ
# s2 ydjQ ydjQ.1
# s2 ydjQ ydjQ.2
# s2 ydjQ ydjQ.3
# s2 ydjQ ydjQ.4
# s2 ydjQ ydjQ.5
# s2 ydjQ ydjQ.6
# s2 ydjQ ydjQ.7
# s3 ydjQ
# s2 yjgB yjgB
# s2 yjgB yjgB.1
# s2 yjgB yjgB.2
# s2 yjgB yjgB.3
# s2 yjgB yjgB.4
# s2 yjgB yjgB.5
# s2 yjgB yjgB.6
# s2 yjgB yjgB.7
# s3 yjgB
# s2 ykfl ykfl
# s2 ykfl ykfl.1
# s2 ykfl ykfl.2
# s2 ykfl ykfl.3
# s2 ykfl ykfl.4
# s2 ykfl ykfl.5
# s2 ykfl ykfl.6
# s2 ykfl ykfl.7
# s3 ykfl
# s2 yncI yncI
# s2 yncI yncI.1
# s2 yncI yncI.2
# s2 yncI yncI.3
# s2 yncI yncI.4
# s2 yncI yncI.5
# s2 yncI yncI.6
# s2 yncI yncI.7
# s3 yncI
# s2 yoaF yoaF
# s2 yoaF yoaF.1
# s2 yoaF yoaF.2
# s2 yoaF yoaF.3
# s2 yoaF yoaF.4
# s2 yoaF yoaF.5
# s2 yoaF yoaF.6
# s2 yoaF yoaF.7
# csv/MG1655 03082019-stats.csv
# s2 crcA crcA
# s2 crcA crcA.1
# s2 crcA crcA.2
# s2 crcA crcA.3
# s2 crcA crcA.4
# s2 crcA crcA.5
# s2 crcA crcA.6
# s2 crcA crcA.7
# s3 crcA
# s2 sspA sspA
# s2 sspA sspA.1
# s2 sspA sspA.2
# s2 sspA sspA.3
# s2 sspA sspA.4
# s2 sspA sspA.5
# s2 sspA sspA.6
# s2 sspA sspA.7
# s3 sspA
# s2 yigL yigL
# s2 yigL yigL.1
# s2 yigL yigL.2
# s2 yigL yigL.3
# s2 yigL yigL.4
# s2 yigL yigL.5
# s2 yigL yigL.6
# s2 yigL yigL.7
# s3 yigL
# s2 yjhG yjhG
# s2 yjhG yjhG.1
# s2 yjhG yjhG.2
# s2 yjhG yjhG.3
# s2 yjhG yjhG.4
# s2 yjhG yjhG.5
# s2 yjhG yjhG.6
# s2 yjhG yjhG.7
# s3 yjhG
# s2 appB appB
# s2 appB appB.1
# s2 appB appB.2
# s2 appB appB.3
# s2 appB appB.4
# s2 appB appB.5
# s2 appB appB.6
# s2 appB appB.7
# s3 appB
# s2 nagK nagK
# s2 nagK nagK.1
# s2 nagK nagK.2
# s2 nagK nagK.3
# s2 nagK nagK.4
# s2 nagK nagK.5
# s2 nagK nagK.6
# s2 nagK nagK.7
# s3 nagK
# s2 appA appA
# s2 appA appA.1
# s2 appA appA.2
# s2 appA appA.3
# s2 appA appA.4
# s2 appA appA.5
# s2 appA appA.6
# s2 appA appA.7
# s3 appA
# s2 yecP yecP
# s2 yecP yecP.1
# s2 yecP yecP.2
# s2 yecP yecP.3
# s2 yecP yecP.4
# s2 yecP yecP.5
# s2 yecP yecP.6
# s2 yecP yecP.7
# s3 yecP
# s2 yihS yihS
# s2 yihS yihS.1
# s2 yihS yihS.2
# s2 yihS yihS.3
# s2 yihS yihS.4
# s2 yihS yihS.5
# s2 yihS yihS.6
# s2 yihS yihS.7
# s3 yihS
# s2 WT WT
# s2 WT WT.1
# s2 WT WT.2
# s2 WT WT.3
# s2 WT WT.4
# s2 WT WT.5
# s2 WT WT.6
# s2 WT WT.7
# csv/MG1655 14062019-stats.csv
# s2 alr alr
# s2 alr alr.1
# s2 alr alr.2
# s2 alr alr.3
# s2 alr alr.4
# s2 alr alr.5
# s2 alr alr.6
# s2 alr alr.7
# s3 alr
# s2 cbpM cbpM
# s2 cbpM cbpM.1
# s2 cbpM cbpM.2
# s2 cbpM cbpM.3
# s2 cbpM cbpM.4
# s2 cbpM cbpM.5
# s2 cbpM cbpM.6
# s2 cbpM cbpM.7
# s3 cbpM
# s2 fixC fixC
# s2 fixC fixC.1
# s2 fixC fixC.2
# s2 fixC fixC.3
# s2 fixC fixC.4
# s2 fixC fixC.5
# s2 fixC fixC.6
# s2 fixC fixC.7
# s3 fixC
# s2 hybG hybG
# s2 hybG hybG.1
# s2 hybG hybG.2
# s2 hybG hybG.3
# s2 hybG hybG.4
# s2 hybG hybG.5
# s2 hybG hybG.6
# s2 hybG hybG.7
# s3 hybG
# s2 hycA hycA
# s2 hycA hycA.1
# s2 hycA hycA.2
# s2 hycA hycA.3
# s2 hycA hycA.4
# s2 hycA hycA.5
# s2 hycA hycA.6
# s2 hycA hycA.7
# s3 hycA
# s2 nirC nirC
# s2 nirC nirC.1
# s2 nirC nirC.2
# s2 nirC nirC.3
# s2 nirC nirC.4
# s2 nirC nirC.5
# s2 nirC nirC.6
# s2 nirC nirC.7
# s3 nirC
# s2 phnH phnH
# s2 phnH phnH.1
# s2 phnH phnH.2
# s2 phnH phnH.3
# s2 phnH phnH.4
# s2 phnH phnH.5
# s2 phnH phnH.6
# s2 phnH phnH.7
# s3 phnH
# s2 WT WT
# s2 WT WT.1
# s2 WT WT.2
# s2 WT WT.3
# s2 WT WT.4
# s2 WT WT.5
# s2 WT WT.6
# s2 WT WT.7
# s3 WT
# s2 ybdA ybdA
# s2 ybdA ybdA.1
# s2 ybdA ybdA.2
# s2 ybdA ybdA.3
# s2 ybdA ybdA.4
# s2 ybdA ybdA.5
# s2 ybdA ybdA.6
# s2 ybdA ybdA.7
# s3 ybdA
# s2 ydcP ydcP
# s2 ydcP ydcP.1
# s2 ydcP ydcP.2
# s2 ydcP ydcP.3
# s2 ydcP ydcP.4
# s2 ydcP ydcP.5
# s2 ydcP ydcP.6
# s2 ydcP ydcP.7
# csv/MG1655 26062019-stats.csv
# s2 agaA agaA
# s2 agaA agaA.1
# s2 agaA agaA.2
# s2 agaA agaA.3
# s2 agaA agaA.4
# s2 agaA agaA.5
# s2 agaA agaA.6
# s2 agaA agaA.7
# s3 agaA
# s2 ldcC ldcC
# s2 ldcC ldcC.1
# s2 ldcC ldcC.2
# s2 ldcC ldcC.3
# s2 ldcC ldcC.4
# s2 ldcC ldcC.5
# s2 ldcC ldcC.6
# s2 ldcC ldcC.7
# s3 ldcC
# s2 lysC lysC
# s2 lysC lysC.1
# s2 lysC lysC.2
# s2 lysC lysC.3
# s2 lysC lysC.4
# s2 lysC lysC.5
# s2 lysC lysC.6
# s2 lysC lysC.7
# s3 lysC
# s2 nagZ nagZ
# s2 nagZ nagZ.1
# s2 nagZ nagZ.2
# s2 nagZ nagZ.3
# s2 nagZ nagZ.4
# s2 nagZ nagZ.5
# s2 nagZ nagZ.6
# s2 nagZ nagZ.7
# s3 nagZ
# s2 osmy osmy
# s2 osmy osmy.1
# s2 osmy osmy.2
# s2 osmy osmy.3
# s2 osmy osmy.4
# s2 osmy osmy.5
# s2 osmy osmy.6
# s2 osmy osmy.7
# s3 osmy
# s2 Rph Rph
# s2 Rph Rph.1
# s2 Rph Rph.2
# s2 Rph Rph.3
# s2 Rph Rph.4
# s2 Rph Rph.5
# s2 Rph Rph.6
# s2 Rph Rph.7
# s3 Rph
# s2 sgcQ sgcQ
# s2 sgcQ sgcQ.1
# s2 sgcQ sgcQ.2
# s2 sgcQ sgcQ.3
# s2 sgcQ sgcQ.4
# s2 sgcQ sgcQ.5
# s2 sgcQ sgcQ.6
# s2 sgcQ sgcQ.7
# s3 sgcQ
# s2 ulaD ulaD
# s2 ulaD ulaD.1
# s2 ulaD ulaD.2
# s2 ulaD ulaD.3
# s2 ulaD ulaD.4
# s2 ulaD ulaD.5
# s2 ulaD ulaD.6
# s2 ulaD ulaD.7
# s3 ulaD
# s2 uxuR uxuR
# s2 uxuR uxuR.1
# s2 uxuR uxuR.2
# s2 uxuR uxuR.3
# s2 uxuR uxuR.4
# s2 uxuR uxuR.5
# s2 uxuR uxuR.6
# s2 uxuR uxuR.7
# s3 uxuR
# s2 WT WT
# s2 WT WT.1
# s2 WT WT.2
# s2 WT WT.3
# s2 WT WT.4
# s2 WT WT.5
# s2 WT WT.6
# s2 WT WT.7
# csv/MG1655 08072019-stats.csv
# s2 Blank Blank
# s2 Blank Blank.1
# s2 Blank Blank.2
# s2 Blank Blank.3
# s2 Blank Blank.4
# s2 Blank Blank.5
# s2 Blank Blank.6
# s2 Blank Blank.7
# s3 Blank
# s2 yjfC yjfC
# s2 yjfC yjfC.1
# s2 yjfC yjfC.2
# s2 yjfC yjfC.3
# s2 yjfC yjfC.4
# s2 yjfC yjfC.5
# s2 yjfC yjfC.6
# s2 yjfC yjfC.7
# s3 yjfC
# s2 yhbS yhbS
# s2 yhbS yhbS.1
# s2 yhbS yhbS.2
# s2 yhbS yhbS.3
# s2 yhbS yhbS.4
# s2 yhbS yhbS.5
# s2 yhbS yhbS.6
# s2 yhbS yhbS.7
# s3 yhbS
# s2 ssuE ssuE
# s2 ssuE ssuE.1
# s2 ssuE ssuE.2
# s2 ssuE ssuE.3
# s2 ssuE ssuE.4
# s2 ssuE ssuE.5
# s2 ssuE ssuE.6
# s2 ssuE ssuE.7
# s3 ssuE
# s2 yhcM yhcM
# s2 yhcM yhcM.1
# s2 yhcM yhcM.2
# s2 yhcM yhcM.3
# s2 yhcM yhcM.4
# s2 yhcM yhcM.5
# s2 yhcM yhcM.6
# s2 yhcM yhcM.7
# s3 yhcM
# s2 yafV yafV
# s2 yafV yafV.1
# s2 yafV yafV.2
# s2 yafV yafV.3
# s2 yafV yafV.4
# s2 yafV yafV.5
# s2 yafV yafV.6
# s2 yafV yafV.7
# s3 yafV
# s2 napC napC
# s2 napC napC.1
# s2 napC napC.2
# s2 napC napC.3
# s2 napC napC.4
# s2 napC napC.5
# s2 napC napC.6
# s2 napC napC.7
# s3 napC
# s2 ybbP ybbP
# s2 ybbP ybbP.1
# s2 ybbP ybbP.2
# s2 ybbP ybbP.3
# s2 ybbP ybbP.4
# s2 ybbP ybbP.5
# s2 ybbP ybbP.6
# s2 ybbP ybbP.7
# s3 ybbP
# s2 ynaA ynaA
# s2 ynaA ynaA.1
# s2 ynaA ynaA.2
# s2 ynaA ynaA.3
# s2 ynaA ynaA.4
# s2 ynaA ynaA.5
# s2 ynaA ynaA.6
# s2 ynaA ynaA.7
# s3 ynaA
# s2 pflC pflC
# s2 pflC pflC.1
# s2 pflC pflC.2
# s2 pflC pflC.3
# s2 pflC pflC.4
# s2 pflC pflC.5
# s2 pflC pflC.6
# s2 pflC pflC.7
# s3 pflC
# s2 WT WT
# s2 WT WT.1
# s2 WT WT.2
# s2 WT WT.3
# s2 WT WT.4
# s2 WT WT.5
# s2 WT WT.6
# s2 WT WT.7
# s3 WT
# s2 Blank.8 Blank.8
# s3 Blank.8
# s2 Blank.9 Blank.9
# s3 Blank.9
# s2 Blank.10 Blank.10
# s3 Blank.10
# s2 Blank.11 Blank.11
# s3 Blank.11
# s2 Blank.12 Blank.12
# s3 Blank.12
# s2 Blank.13 Blank.13
# s3 Blank.13
# s2 Blank.14 Blank.14
# s3 Blank.14
# s2 Blank.15 Blank.15
# csv/MG1655 28062019-stats.csv
# s2 Paac Paac
# s2 Paac Paac.1
# s2 Paac Paac.2
# s2 Paac Paac.3
# s2 Paac Paac.4
# s2 Paac Paac.5
# s2 Paac Paac.6
# s2 Paac Paac.7
# s3 Paac
# s2 WT WT
# s2 WT WT.1
# s2 WT WT.2
# s2 WT WT.3
# s2 WT WT.4
# s2 WT WT.5
# s2 WT WT.6
# s2 WT WT.7
# s3 WT
# s2 yajQ yajQ
# s2 yajQ yajQ.1
# s2 yajQ yajQ.2
# s2 yajQ yajQ.3
# s2 yajQ yajQ.4
# s2 yajQ yajQ.5
# s2 yajQ yajQ.6
# s2 yajQ yajQ.7
# s3 yajQ
# s2 ybit ybit
# s2 ybit ybit.1
# s2 ybit ybit.2
# s2 ybit ybit.3
# s2 ybit ybit.4
# s2 ybit ybit.5
# s2 ybit ybit.6
# s2 ybit ybit.7
# s3 ybit
# s2 ycaD ycaD
# s2 ycaD ycaD.1
# s2 ycaD ycaD.2
# s2 ycaD ycaD.3
# s2 ycaD ycaD.4
# s2 ycaD ycaD.5
# s2 ycaD ycaD.6
# s2 ycaD ycaD.7
# s3 ycaD
# s2 Yeha Yeha
# s2 Yeha Yeha.1
# s2 Yeha Yeha.2
# s2 Yeha Yeha.3
# s2 Yeha Yeha.4
# s2 Yeha Yeha.5
# s2 Yeha Yeha.6
# s2 Yeha Yeha.7
# s3 Yeha
# s2 yfbM yfbM
# s2 yfbM yfbM.1
# s2 yfbM yfbM.2
# s2 yfbM yfbM.3
# s2 yfbM yfbM.4
# s2 yfbM yfbM.5
# s2 yfbM yfbM.6
# s2 yfbM yfbM.7
# s3 yfbM
# s2 yfjo yfjo
# s2 yfjo yfjo.1
# s2 yfjo yfjo.2
# s2 yfjo yfjo.3
# s2 yfjo yfjo.4
# s2 yfjo yfjo.5
# s2 yfjo yfjo.6
# s2 yfjo yfjo.7
# s3 yfjo
# s2 ygcQ ygcQ
# s2 ygcQ ygcQ.1
# s2 ygcQ ygcQ.2
# s2 ygcQ ygcQ.3
# s2 ygcQ ygcQ.4
# s2 ygcQ ygcQ.5
# s2 ygcQ ygcQ.6
# s2 ygcQ ygcQ.7
# csv/MG1655 02082019-stats.csv
# s2 uxaA uxaA
# s2 uxaA uxaA.1
# s2 uxaA uxaA.2
# s2 uxaA uxaA.3
# s2 uxaA uxaA.4
# s2 uxaA uxaA.5
# s2 uxaA uxaA.6
# s2 uxaA uxaA.7
# s3 uxaA
# s2 yagQ yagQ
# s2 yagQ yagQ.1
# s2 yagQ yagQ.2
# s2 yagQ yagQ.3
# s2 yagQ yagQ.4
# s2 yagQ yagQ.5
# s2 yagQ yagQ.6
# s2 yagQ yagQ.7
# s3 yagQ
# s2 caic caic
# s2 caic caic.1
# s2 caic caic.2
# s2 caic caic.3
# s2 caic caic.4
# s2 caic caic.5
# s2 caic caic.6
# s2 caic caic.7
# s3 caic
# s2 paoB paoB
# s2 paoB paoB.1
# s2 paoB paoB.2
# s2 paoB paoB.3
# s2 paoB paoB.4
# s2 paoB paoB.5
# s2 paoB paoB.6
# s2 paoB paoB.7
# s3 paoB
# s2 xdhB xdhB
# s2 xdhB xdhB.1
# s2 xdhB xdhB.2
# s2 xdhB xdhB.3
# s2 xdhB xdhB.4
# s2 xdhB xdhB.5
# s2 xdhB xdhB.6
# s2 xdhB xdhB.7
# s3 xdhB
# s2 agaR agaR
# s2 agaR agaR.1
# s2 agaR agaR.2
# s2 agaR agaR.3
# s2 agaR agaR.4
# s2 agaR agaR.5
# s2 agaR agaR.6
# s2 agaR agaR.7
# s3 agaR
# s2 yagL yagL
# s2 yagL yagL.1
# s2 yagL yagL.2
# s2 yagL yagL.3
# s2 yagL yagL.4
# s2 yagL yagL.5
# s2 yagL yagL.6
# s2 yagL yagL.7
# s3 yagL
# s2 pfID pfID
# s2 pfID pfID.1
# s2 pfID pfID.2
# s2 pfID pfID.3
# s2 pfID pfID.4
# s2 pfID pfID.5
# s2 pfID pfID.6
# s2 pfID pfID.7
# s3 pfID
# s2 uxaC uxaC
# s2 uxaC uxaC.1
# s2 uxaC uxaC.2
# s2 uxaC uxaC.3
# s2 uxaC uxaC.4
# s2 uxaC uxaC.5
# s2 uxaC uxaC.6
# s2 uxaC uxaC.7
# s3 uxaC
# s2 WT WT
# s2 WT WT.1
# s2 WT WT.2
# s2 WT WT.3
# s2 WT WT.4
# s2 WT WT.5
# s2 WT WT.6
# s2 WT WT.7
# csv/MG1655 27062019-stats.csv
# s2 abgR abgR
# s2 abgR abgR.1
# s2 abgR abgR.2
# s2 abgR abgR.3
# s2 abgR abgR.4
# s2 abgR abgR.5
# s2 abgR abgR.6
# s2 abgR abgR.7
# s3 abgR
# s2 casE casE
# s2 casE casE.1
# s2 casE casE.2
# s2 casE casE.3
# s2 casE casE.4
# s2 casE casE.5
# s2 casE casE.6
# s2 casE casE.7
# s3 casE
# s2 fabR fabR
# s2 fabR fabR.1
# s2 fabR fabR.2
# s2 fabR fabR.3
# s2 fabR fabR.4
# s2 fabR fabR.5
# s2 fabR fabR.6
# s2 fabR fabR.7
# s3 fabR
# s2 flu flu
# s2 flu flu.1
# s2 flu flu.2
# s2 flu flu.3
# s2 flu flu.4
# s2 flu flu.5
# s2 flu flu.6
# s2 flu flu.7
# s3 flu
# s2 fruB fruB
# s2 fruB fruB.1
# s2 fruB fruB.2
# s2 fruB fruB.3
# s2 fruB fruB.4
# s2 fruB fruB.5
# s2 fruB fruB.6
# s2 fruB fruB.7
# s3 fruB
# s2 fsR fsR
# s2 fsR fsR.1
# s2 fsR fsR.2
# s2 fsR fsR.3
# s2 fsR fsR.4
# s2 fsR fsR.5
# s2 fsR fsR.6
# s2 fsR fsR.7
# s3 fsR
# s2 ssuA ssuA
# s2 ssuA ssuA.1
# s2 ssuA ssuA.2
# s2 ssuA ssuA.3
# s2 ssuA ssuA.4
# s2 ssuA ssuA.5
# s2 ssuA ssuA.6
# s2 ssuA ssuA.7
# s3 ssuA
# s2 WT WT
# s2 WT WT.1
# s2 WT WT.2
# s2 WT WT.3
# s2 WT WT.4
# s2 WT WT.5
# s2 WT WT.6
# s2 WT WT.7
# s3 WT
# s2 ybdk ybdk
# s2 ybdk ybdk.1
# s2 ybdk ybdk.2
# s2 ybdk ybdk.3
# s2 ybdk ybdk.4
# s2 ybdk ybdk.5
# s2 ybdk ybdk.6
# s2 ybdk ybdk.7
# s3 ybdk
# s2 yiaG yiaG
# s2 yiaG yiaG.1
# s2 yiaG yiaG.2
# s2 yiaG yiaG.3
# s2 yiaG yiaG.4
# s2 yiaG yiaG.5
# s2 yiaG yiaG.6
# s2 yiaG yiaG.7
# csv/MG1655 05082019-stats.csv
# s2 thiQ thiQ
# s2 thiQ thiQ.1
# s2 thiQ thiQ.2
# s2 thiQ thiQ.3
# s2 thiQ thiQ.4
# s2 thiQ thiQ.5
# s2 thiQ thiQ.6
# s2 thiQ thiQ.7
# s3 thiQ
# s2 paaC paaC
# s2 paaC paaC.1
# s2 paaC paaC.2
# s2 paaC paaC.3
# s2 paaC paaC.4
# s2 paaC paaC.5
# s2 paaC paaC.6
# s2 paaC paaC.7
# s3 paaC
# s2 dnaT dnaT
# s2 dnaT dnaT.1
# s2 dnaT dnaT.2
# s2 dnaT dnaT.3
# s2 dnaT dnaT.4
# s2 dnaT dnaT.5
# s2 dnaT dnaT.6
# s2 dnaT dnaT.7
# s3 dnaT
# s2 pfkA pfkA
# s2 pfkA pfkA.1
# s2 pfkA pfkA.2
# s2 pfkA pfkA.3
# s2 pfkA pfkA.4
# s2 pfkA pfkA.5
# s2 pfkA pfkA.6
# s2 pfkA pfkA.7
# s3 pfkA
# s2 glpX glpX
# s2 glpX glpX.1
# s2 glpX glpX.2
# s2 glpX glpX.3
# s2 glpX glpX.4
# s2 glpX glpX.5
# s2 glpX glpX.6
# s2 glpX glpX.7
# s3 glpX
# s2 fkpA fkpA
# s2 fkpA fkpA.1
# s2 fkpA fkpA.2
# s2 fkpA fkpA.3
# s2 fkpA fkpA.4
# s2 fkpA fkpA.5
# s2 fkpA fkpA.6
# s2 fkpA fkpA.7
# s3 fkpA
# s2 cynX cynX
# s2 cynX cynX.1
# s2 cynX cynX.2
# s2 cynX cynX.3
# s2 cynX cynX.4
# s2 cynX cynX.5
# s2 cynX cynX.6
# s2 cynX cynX.7
# s3 cynX
# s2 recF recF
# s2 recF recF.1
# s2 recF recF.2
# s2 recF recF.3
# s2 recF recF.4
# s2 recF recF.5
# s2 recF recF.6
# s2 recF recF.7
# s3 recF
# s2 bipA bipA
# s2 bipA bipA.1
# s2 bipA bipA.2
# s2 bipA bipA.3
# s2 bipA bipA.4
# s2 bipA bipA.5
# s2 bipA bipA.6
# s2 bipA bipA.7
# s3 bipA
# s2 WT WT
# s2 WT WT.1
# s2 WT WT.2
# s2 WT WT.3
# s2 WT WT.4
# s2 WT WT.5
# s2 WT WT.6
# s2 WT WT.7
# last s3 WT

# %%
strain
# Out:
# 'WT.7'

# %%
df = pd.DataFrame(yield_list) 
df = df.set_index([pd.Index(name_list)])
df
df.to_csv('yield_all_strains.csv')

df = pd.DataFrame(growth_rate_list) 
df = df.set_index([pd.Index(name_list)])
df
df.to_csv('growth_rate_all_strains.csv')

# %% [markdown]
# # run for one file .csv

# %%
import pandas as pd 
import os
fn = "MG1655 05082019.csv"
folder = fn.split('.')[0]
mkdir_p(folder)
data = pd.read_csv("MG1655 05082019.csv") 
# Preview the first 5 lines of the loaded data 
#data.head()

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
time = data['Time [s]']
m_od = data.iloc[0:,1:]
strains = list(m_od.columns)
t = time.values

t_k = (t[1:len(t)] - t[0:len(t)-1])/3600
t_k = np.cumsum(t_k)
t_k = np.insert(t_k,0,0)
t_k = t_k.reshape(-1,1)
t = t_k

blank_od = 0.04
pre_max_v = 0.7

growth_rate_dict = dict()
lag_phase_dict = dict()
yield_dict = dict()
for name in strains:
    od = m_od[name].values
    od_array = od - np.min(blank_od)
    od_array = np.squeeze(np.asarray(od_array))
    sOD = smooth(od_array)    
    sOD_log = np.log(sOD)

    coef_OD, dt_pad = computeDerivetive_od(t, sOD)
    ind_max_dODdt = np.argmax(coef_OD)
    OD_exp = sOD[ind_max_dODdt]
    time_max_dODdt = dt_pad[ind_max_dODdt]
    start_positive = getPostiveStart(sOD)
    if start_positive > 0:
        print fn,'found negative od ', start_positive    
    lag_phase_pre = time_max_dODdt - np.log(OD_exp/sOD[start_positive])/pre_max_v
    m = t < lag_phase_pre
    start_ind = np.sum(m)

    time_max_od,time_left, time_right,left_side_exp,right_side_exp,small_t,tan = getTimepoints(coef_OD,sOD_log,dt_pad,start_ind)

    time_max_dODdt = dt_pad[ind_max_dODdt]

    od_max_coef = coef_OD[ind_max_dODdt]

    ind = np.argmax(coef_OD)        
    max_v = coef_OD[ind]    
    growth_rate = max_v
    
    # Update lag_phase using growth rate in an estimated window
    lag_phase_pre = time_max_dODdt - np.log(OD_exp/sOD[start_positive])/max_v
    lag_phase = lag_phase_pre

    sta_index = getStationaryTime(sOD)
    t_sta = dt_pad[sta_index]
    
    yield_mean = np.mean(sOD[sta_index:])
    print name+'yield'+"="+str(yield_mean)
    
        
    x = t_k
    y = sOD_log
    plt.plot(x,y,label='log(OD)')
    plt.plot(x,y,small_t,tan,'--r',label='log(OD)')
    plt.title(name)
    plt.xlabel("time")
    w = coef_OD
    plt.plot(x, w,label='dOD/dt/OD') # can c                
    plt.axvline(x=time_max_od,linestyle=':',color='green')
    plt.legend()
    plt.savefig(os.path.join(folder,name +'-dODdtOD.png'))
    plt.close()   

    plt.plot(x,sOD,label='OD')    
    plt.axvline(x=time_left,linestyle=':',color='red')
    plt.axvline(x=time_max_od,linestyle=':',color='green')
    plt.axvline(x=t_sta,linestyle=':',color='yellow')
    plt.axvline(x=time_right,linestyle=':',color='red')
    plt.axvline(x=lag_phase,linestyle=':',color='purple')    
    plt.xlabel('time')
    plt.title(name)        
    plt.legend()
    plt.savefig(os.path.join(folder,name +'-OD.png'))
    plt.close()
    
    growth_rate_dict[name] = growth_rate
    lag_phase_dict[name] = lag_phase
    yield_dict[name] = yield_mean
    
df = pd.DataFrame.from_dict([growth_rate_dict,lag_phase_dict, yield_dict])
df = df.transpose()
df2 = df.reindex(strains)
df2.columns = ['Growth Rate', 'Lag Phase', 'yield']
df2.to_csv(os.path.join('.',name +'-stats.csv'))
